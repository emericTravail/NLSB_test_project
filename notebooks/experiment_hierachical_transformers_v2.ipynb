# %%
# !nvidia-smi
# Out:
# Mon Feb 23 19:28:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P0             61W /  400W |    4542MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1380      C   /usr/bin/python3                       4530MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
import gc
import sys
import torch
import json
import numpy as np
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report
from torch.utils.data import TensorDataset, DataLoader, random_split, Dataset
from torch import nn
from transformers import AutoTokenizer, AutoModel, AutoModelForMaskedLM, BertTokenizerFast, BertTokenizer, BertForSequenceClassification, DataCollatorForLanguageModeling, TrainingArguments, Trainer, AutoConfig
import matplotlib.pyplot as plt
import torch.nn.functional as F
import random
import torch
import datasets

# %%
print('Working dir:', os.getcwd())
# Out:
# Working dir: /content

# %%
# All models
BERT = "bert-base-multilingual-cased"
ROBERTA = "FacebookAI/xlm-roberta-base" # Roberta multilangual
CAMEMBERT = "camembert-base" # RoBerta adapted for french
DISTIL_CAMEMBERT = "cmarkea/distilcamembert-base" # CAMEMBERT french smaller
LONGFORMER = "abazoge/DrLongformer"
BIGBIRD = "google/bigbird-roberta-base"

# %% [markdown]
# Data Preprocessing

# %%
"""
Module to transform data to be consumable by model
"""

class DatabaseToBertDataset():
    def __init__(self, model_name):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name) # ("bert-base-multilingual-cased")
        self.tokenizerChunkLen = self.tokenizer.model_max_length

        config = AutoConfig.from_pretrained(model_name)
        self.maxTokensLength = config.max_position_embeddings


        # "allenai/longformer-base-4096" has no max_length
        if model_name == CAMEMBERT or DISTIL_CAMEMBERT:
            self.maxTokensLength = 512
        if model_name == LONGFORMER:
            self.maxTokensLength = 4096

    def _tokenize(self, df: str) -> pd.DataFrame:
        """Tokenizer function"""
        tokenized = self.tokenizer(
            df["email"].to_list(),
            df["bill"].to_list(),
            padding='max_length',
            max_length=self.maxTokensLength,
            truncation=True,
            stride=128,                        # overlap between chunks
            return_overflowing_tokens=True,    # keep extra chunks
            return_offsets_mapping=True,       # optional: track positions in original text
            return_tensors="pt"                # PyTorch tensors
        )

        # input(tokenized.keys())

        # print(type(tokenized))
        # print(tokenized['input_ids'].shape)
        # print(tokenized['token_type_ids'].shape)
        # print(tokenized['attention_mask'].shape)
        # print(tokenized['offset_mapping'].shape)
        # print(tokenized['overflow_to_sample_mapping'].shape)
        # input('MMMM')

        return tokenized

    def tokenize_by_row(self, row: pd.Series):
        text = self._join_text_fields(row)
        tokenized = self.tokenizer(
            text,
            padding='max_length',
            max_length=self.maxTokensLength,
            truncation=True,
            stride=128,                        # overlap between chunks
            return_overflowing_tokens=True,    # keep extra chunks
            return_offsets_mapping=True,       # optional: track positions in original text
            return_tensors="pt"                # PyTorch tensors
        )

        return tokenized

    def _join_text_fields(self, row):
        parts = []
        for k in ["email", "bill"]:
            if row[k]:
                parts.append(row[k])
        return " [SEP] ".join(parts)

    def _encode_labels(self, df: pd.DataFrame) -> tuple[pd.DataFrame, np.ndarray]:
        """Encode labels"""

        df = df.copy()
        # Get unique labels from labels description
        with open('labels.json', 'r') as file:
            labels = json.load(file)['etiquettes']
        labelIds = [label['id'] for label in labels]

        # Format original labels
        df['labels'] = df['labels'].apply(
            lambda x: x.split('|') if isinstance(x, str) else []
        )

        # Encode
        mlb = MultiLabelBinarizer(classes=labelIds)
        encoded = mlb.fit_transform(df['labels'])
        df = pd.concat(
            [df, pd.DataFrame(encoded, columns=mlb.classes_)],
            axis=1
        )
        df = df.drop(columns='labels')

        return df, mlb.classes_


    def execute(self, df : pd.DataFrame) -> tuple[dict[torch.Tensor], np.ndarray]:
        """
        Transform from database to dataset consumable by model
        """
        df = df.copy()
        # Tokenize ('input_ids' 'attention_mask''token_type_ids' 'overflow_to_sample_mapping')
        tokenized = df.apply(lambda row: self.tokenize_by_row(row), axis=1)


        labels = None
        if 'labels' in df.columns:
            df, labelNames = self._encode_labels(df)
            labels = torch.tensor(df[labelNames].to_numpy())

        return tokenized.to_list(),  labels, labelNames

# %%
# def collate_variable_docs(batch, pad_token_id=0):
#     """
#     batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
#     where each input_ids has shape [num_chunks, 512]
#     """
#
#     input_ids_list, attn_list, token_type_list, label_list = zip(*batch)
#
#     # Find max num_chunks in this batch
#     max_chunks = max(x.shape[0] for x in input_ids_list)
#     chunk_len = input_ids_list[0].shape[1]
#
#     def pad_to_max_chunks(x, pad_val = 0):
#         pad_chunks = max_chunks - x.shape[0]
#         if pad_chunks > 0:
#             pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
#             x = torch.cat([x, pad], dim=0)
#         return x
#
#     input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
#     attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
#     token_types = torch.stack([pad_to_max_chunks(x) for x in token_type_list])
#     labels = torch.stack(label_list)
#
#     return input_ids, attn_mask, token_types, labels
#
# class BertTokenizedDataset(Dataset):
#     def __init__(self, data, labels):
#         self.data = data
#         self.labels = labels
#
#     def __len__(self):
#         return len(self.data)
#
#     def __getitem__(self, idx):
#         # Just return what you already have
#         sample = self.data[idx]
#         x = []
#         return sample['input_ids'], sample['attention_mask'], sample['token_type_ids'], self.labels[idx]
#
# databaseToBertDataset = DatabaseToBertDataset(model_name="bert-base-multilingual-cased")
# df = pd.read_csv('data.csv')
# data, labels, labels_list = databaseToBertDataset.execute(df)
#
#
# dataset = BertTokenizedDataset(
#     data,
#     labels,
# )
#
#
# train_loader = DataLoader(dataset, batch_size=4, shuffle=True,
#                           collate_fn=(lambda batch: collate_variable_docs(batch, databaseToBertDataset.tokenizer.pad_token_id)))
#
#
# for batch_idx, batch in enumerate(train_loader):
#
#     input_ids = batch[0]
#     attention_mask = batch[1]
#     token_type_ids = batch[2]
#     labels = batch[3]
#
#     print('asdasdasd')
#     print(input_ids[0])
#     print(attention_mask.shape)
#     print(token_type_ids.shape)
#     print(labels.shape)
#

# %% [markdown]
# Models

# %%
class BertHierachicalClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)


        self.chunk_transformer = nn.TransformerEncoderLayer(
            d_model=self.bert.config.hidden_size,
            nhead=8,
            batch_first=True
        )

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]
        token_type_ids = batch[2]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)
        if token_type_ids is not None:
            token_type_ids = token_type_ids.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document


        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierachicalClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(0.2)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierachicalLsanClassifier(nn.Module):
    def __init__(self, model_name, num_labels, model_dapt=None, d_a=200, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        if model_dapt is None:
          self.bert = AutoModel.from_pretrained(self.modelName)
        else:
          self.bert = model_dapt
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(0.2)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)

        # === LSAN Part ===
        # Self-attention per label
        self.W1 = nn.Linear(H, d_a)          # (H → d_a)
        self.W2 = nn.Linear(d_a, num_labels) # (d_a → L)

        # Label attention
        self.C = nn.Parameter(torch.randn(num_labels, H))

        # Adaptive Attention
        self.W3 = nn.Parameter(torch.randn(H))
        self.W4 = nn.Parameter(torch.randn(H))

        # Classifier
        # self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels) OLD

        self.W_cls = nn.Parameter(torch.randn(num_labels, H))  # (L, H)
        self.b_cls = nn.Parameter(torch.zeros(num_labels))

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings) # (batch_size, nbr_encoding, encoding_dim)
        # doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # === LSAN Part ===
        # Self-attention per label
        Q_s = torch.tanh(self.W1(doc_embeds)) # [batch_size, nbr_encoding, d_a]
        K_s = self.W2(Q_s) # [batch_size, nbr_encoding, nbr_labels]
        A_s = torch.softmax(K_s.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_s = torch.matmul(A_s, doc_embeds) # [batch_size, nbr_labels, encoding_dim]

        # Label-attention
        A_l = torch.matmul(doc_embeds, self.C.T) # [batch_size, nbr_encoding, nbr_labels]
        A_l = torch.softmax(A_l.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_l = torch.matmul(A_l, doc_embeds) # [batch_size, nbr_labels, nbr_encoding]

        # Adaptive Attention Fusion
        a = torch.sigmoid(torch.matmul(M_s, self.W3)) # [batch_size, nbr_labels]
        b = torch.sigmoid(torch.matmul(M_l, self.W4)) # [batch_size, nbr_labels]
        s = a + b + 1e-8 # a_i + b_i = 1
        a = a / s
        b = b / s
        M_j = a.unsqueeze(-1) * M_s + b.unsqueeze(-1) * M_l # [batch_size, nbr_labels, nbr_encoding]



        # Classification
        out = (M_j * self.W_cls.unsqueeze(0)).sum(-1) + self.b_cls

        return out

class CamembertHierachicalLsanClassifierDep(nn.Module):
    def __init__(self, model_name, num_labels, model_dapt=None, d_a=200, drop_out = 0.2, freeze_bert=False):
        super().__init__()
        print(f'Init model CamembertHierachicalLsanClassifierDep(model_dapt={type(model_dapt)}, model_name={model_name}, num_labels={num_labels}, d_a={d_a}, drop_out={drop_out} freeze_bert={freeze_bert})')
        self.modelName = model_name
        if model_dapt is None:
          self.bert = AutoModel.from_pretrained(self.modelName)
        else:
          self.bert = model_dapt
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(drop_out)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)

        # === LSAN Part ===
        # Self-attention per label
        self.W1 = nn.Linear(H, d_a)          # (H → d_a)
        self.W2 = nn.Linear(d_a, num_labels) # (d_a → L)

        # Label attention
        self.C = nn.Parameter(torch.randn(num_labels, H))

        # Adaptive Attention
        self.W3 = nn.Parameter(torch.randn(H))
        self.W4 = nn.Parameter(torch.randn(H))

        # Classifier
        self.label_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)
        # self.classifier = nn.Linear(H, num_labels)
        hidden = H // 2
        self.classifier = nn.Sequential(
            nn.LayerNorm(H),
            nn.Linear(H, hidden),
            nn.GELU(),
            nn.Dropout(drop_out),
            nn.Linear(hidden, num_labels)
        )

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = x[0]
        attention_mask = x[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings) # (batch_size, nbr_encoding, encoding_dim)
        # doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # === LSAN Part ===
        # Self-attention per label
        Q_s = torch.tanh(self.W1(doc_embeds)) # [batch_size, nbr_encoding, d_a]
        K_s = self.W2(Q_s) # [batch_size, nbr_encoding, nbr_labels]
        A_s = torch.softmax(K_s.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_s = torch.matmul(A_s, doc_embeds) # [batch_size, nbr_labels, encoding_dim]

        # Label-attention
        A_l = torch.matmul(doc_embeds, self.C.T) # [batch_size, nbr_encoding, nbr_labels]
        A_l = torch.softmax(A_l.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_l = torch.matmul(A_l, doc_embeds) # [batch_size, nbr_labels, nbr_encoding]

        # Adaptive Attention Fusion
        a = torch.sigmoid(torch.matmul(M_s, self.W3)) # [batch_size, nbr_labels]
        b = torch.sigmoid(torch.matmul(M_l, self.W4)) # [batch_size, nbr_labels]
        s = a + b + 1e-8 # a_i + b_i = 1
        a = a / s
        b = b / s
        M_j = a.unsqueeze(-1) * M_s + b.unsqueeze(-1) * M_l # [batch_size, nbr_labels, nbr_encoding]

        # Classification
        M_j_aggragated = self.label_transformer(M_j) # [batch_size, nbr_labels, nbr_encoding]
        M_j_aggragated = M_j_aggragated.mean(dim=1) # [batch_size, nbr_encoding]
        out = self.classifier(self.dropout(M_j_aggragated))

        return out

class CamembertHierachicalClassifierV2(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)


        self.chunk_transformer = nn.TransformerEncoderLayer(
            d_model=self.bert.config.hidden_size,
            nhead=8,
            batch_first=True
        )

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT (TAKE ALL OUTPUT)
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        token_emb = outputs.last_hidden_state              # [B*N, L, H]
        mask = attention_mask.unsqueeze(-1).float()        # [B*N, L, 1]

        # masked mean pooling
        sum_emb = (token_emb * mask).sum(dim=1)            # [B*N, H]
        len_emb = mask.sum(dim=1).clamp(min=1e-6)          # [B*N, 1]
        chunk_embeddings = sum_emb / len_emb               # [B*N, H]

        chunk_embeddings = chunk_embeddings.view(B, N, -1) # [B, N, H]

        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierarchicalGRUClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False, gru_hidden=384, num_gru_layers=1):
        super().__init__()

        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)

        hidden_size = self.bert.config.hidden_size

        # ---- GLOBAL ENCODER: BiGRU over chunks ----
        self.gru = nn.GRU(
            input_size=hidden_size,
            hidden_size=gru_hidden,
            num_layers=num_gru_layers,
            batch_first=True,
            bidirectional=True
        )

        self.dropout = nn.Dropout(0.2)

        # Final classifier: takes BiGRU output (2*hidden because bidirectional)
        self.classifier = nn.Linear(gru_hidden * 2, num_labels)

        # Optionally freeze BERT
        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False


    def forward(self, batch):
        input_ids = batch[0]          # (B, N, L)
        attention_mask = batch[1]     # (B, N, L)

        B, N, L = input_ids.shape

        # ---- Flatten chunks so BERT can process them in one batch ----
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # ---- Local transformer over tokens ----
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
        )

        # One embedding per chunk → [CLS] or pooler_output
        chunk_emb = outputs.last_hidden_state[:, 0, :]     # (B*N, hidden)
        # If CamemBERT returns None for pooler_output, use CLS token:
        # chunk_embeddings = outputs.last_hidden_state[:, 0, :]

        # Rebuild (B, N, hidden)
        chunk_emb = chunk_emb.view(B, N, -1)

        # GRU
        # h_n: (num_layers * num_directions, B, hidden)
        _, h_n = self.gru(chunk_emb)

        # Extract final BiGRU state
        # h_n[-2] = final state of backward
        # h_n[-1] = final state of forward
        h_forward = h_n[-1]
        h_backward = h_n[-2]
        doc_rep = torch.cat([h_backward, h_forward], dim=-1)

        logits = self.classifier(self.dropout(doc_rep))

        return logits


class LongformerClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        # "allenai/longformer-base-4096" NOT IN FRENCH... :(
        self.modelName = LONGFORMER
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids, attention_mask = x

        # BERT outputs all hidden states
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Apply dropout + classification on the pooled [CLS] representation
        out = self.classifier(self.dropout(pooled_output))

        return out

class BigbirdClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = BIGBIRD
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids, attention_mask = x

        # BERT outputs all hidden states
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Apply dropout + classification on the pooled [CLS] representation
        out = self.classifier(self.dropout(pooled_output))

        return out

# %% [markdown]
# Evaluate

# %%
def init_eval_metrics() -> dict[list[float|dict]]:
    """
    Init of the evaluation metrics
    """
    return {
        'loss': [],
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1_micro': [],
        'f1_macro_avg': [],
        'f1_weighted_avg': [],
        'f1_macro': []
    }

def compute_eval_metrics(loss, all_labels, all_preds, labels_list) -> dict[list[float]]:
  """
  Computes evaluation metrics
  """
  f1Report = classification_report(all_labels, all_preds, target_names=labels_list, output_dict=True, zero_division=0)


  evalMetric = init_eval_metrics()
  evalMetric['loss'].append(loss)
  evalMetric['accuracy'].append(accuracy_score(all_labels, all_preds))
  evalMetric['precision'].append(f1Report["micro avg"]["precision"])
  evalMetric['recall'].append(f1Report["micro avg"]["recall"])
  evalMetric['f1_micro'].append(f1Report["micro avg"]["f1-score"])
  evalMetric['f1_macro_avg'].append(f1Report["macro avg"]["f1-score"])
  evalMetric['f1_weighted_avg'].append(f1Report["weighted avg"]["f1-score"])
  evalMetric['f1_macro'].append(f1Report)

  return evalMetric


def save_eval_metrics(eval_metrics, evalMetric):
    """
    Saves metrics
    """
    for metricName, val in eval_metrics.items():
        eval_metrics[metricName] = eval_metrics[metricName] + evalMetric[metricName]

def print_eval_metrics(eval_metrics):
    """
    Prints mean metrics
    """
    loss = sum(eval_metrics['loss'])/len(eval_metrics['loss'])
    accuracy = sum(eval_metrics['accuracy'])/len(eval_metrics['accuracy'])
    precision = sum(eval_metrics['precision'])/len(eval_metrics['precision'])
    recall = sum(eval_metrics['recall'])/len(eval_metrics['recall'])
    f1Micro = sum(eval_metrics['f1_micro'])/len(eval_metrics['f1_micro'])
    f1MacroAvg = sum(eval_metrics['f1_macro_avg'])/len(eval_metrics['f1_macro_avg'])


    print(f"  Accuracy: {accuracy:.4f} F1-Micro: {f1Micro:.4f} F1-Macro-Avg {f1MacroAvg:.4f} Precision: {precision:.4f} Recall: {recall:.4f}")


def eval_metrics_to_df(eval_metrics) -> tuple[pd.DataFrame]:
    """
    Full display all metrics
    """

    # Golbal metrics
    globalMetrics = {}
    for metricName, val in eval_metrics.items():
        if 'f1_macro' == metricName:
          continue
        valMean = sum(eval_metrics[metricName])/len(eval_metrics[metricName])
        globalMetrics[metricName] = valMean
    globalMetricsDf = pd.DataFrame([globalMetrics])


    # Label metrics
    f1MacrosDfs = [pd.DataFrame(r).transpose() for r in eval_metrics['f1_macro']]
    f1MacrosDf = pd.concat(f1MacrosDfs).groupby(level=0).mean(numeric_only=True)
    f1MacrosDf = f1MacrosDf.drop(index=["micro avg", "macro avg", "weighted avg", "samples avg"])

    return globalMetricsDf, f1MacrosDf


def plot_losses(trainLosses, evalLosses):
    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(trainLosses, label='Training Loss', marker='o')
    plt.plot(evalLosses, label='Validation Loss', marker='o')

    plt.yscale('log')

    plt.title('Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# Train

# %%
def collate_variable(batch, pad_token_id=0):
    """
    batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
    where each input_ids has shape [num_chunks, 512]
    """

    input_ids_list, attn_list, token_type_list, label_list = zip(*batch)

    # Find max num_chunks in this batch
    max_chunks = max(x.shape[0] for x in input_ids_list)
    chunk_len = input_ids_list[0].shape[1]

    def pad_to_max_chunks(x, pad_val = 0):
        pad_chunks = max_chunks - x.shape[0]
        if pad_chunks > 0:
            pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
            x = torch.cat([x, pad], dim=0)
        return x

    input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
    attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
    token_types = torch.stack([pad_to_max_chunks(x) for x in token_type_list])
    labels = torch.stack(label_list).float()

    return input_ids, attn_mask, token_types, labels

def collate_variable_no_token_types(batch, pad_token_id=0):
    """
    batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
    where each input_ids has shape [num_chunks, 512]
    """

    input_ids_list, attn_list, label_list = zip(*batch)

    # Find max num_chunks in this batch
    max_chunks = max(x.shape[0] for x in input_ids_list)
    chunk_len = input_ids_list[0].shape[1]

    def pad_to_max_chunks(x, pad_val = 0):
        pad_chunks = max_chunks - x.shape[0]
        if pad_chunks > 0:
            pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
            x = torch.cat([x, pad], dim=0)
        return x

    input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
    attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
    labels = torch.stack(label_list).float()

    return input_ids, attn_mask, labels

class TokenizedDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        self.collateFunc = collate_variable

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Just return what you already have
        sample = self.data[idx]
        x = []
        return sample['input_ids'], sample['attention_mask'], sample['token_type_ids'], self.labels[idx]


class TokenizedDatasetNoType(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        self.collateFunc = collate_variable_no_token_types

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Just return what you already have
        sample = self.data[idx]
        x = []
        return sample['input_ids'], sample['attention_mask'], self.labels[idx]

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

    # For multi-GPU
    torch.cuda.manual_seed_all(seed)

    # Make cuDNN deterministic (slower but reproducible)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
def pretrain_model2(model_name, trainDf, train_data, tokenizer):

  def tok(batch):
    return tokenizer(batch["text"], truncation=True, max_length=512)


  model = AutoModelForMaskedLM.from_pretrained(model_name)
  model_name_dapt = model_name + '_dapt'

  texts = trainDf["email"].astype(str).fillna("") + trainDf["bill"].astype(str).fillna("")
  texts = texts.tolist()
  enc = tokenizer(
      texts,
      truncation=True,
      padding=True,               # usually better for chunking
      max_length=512,
      return_overflowing_tokens=True,
      stride=128,                  # overlap between chunks
  )
  # print(train_data)
  # input('...')

  # DataCollatorForLanguageModeling

  collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=True,
    mlm_probability=0.15
  )

  args = TrainingArguments(
      output_dir=model_name_dapt,
      per_device_train_batch_size=16,
      gradient_accumulation_steps=2,   # acts like batch 32
      learning_rate=5e-5,
      weight_decay=0.01,
      warmup_ratio=0.06,
      num_train_epochs=1,              # start with 1; try 2–3 if you have lots of data
      fp16=True,                       # use bf16=True if on Ampere+ and prefer it
      logging_steps=100,
      save_steps=1000,
      save_total_limit=2,
      report_to="none",
  )

  print(enc.data.keys())
  print(type(enc.data))
  print(enc.data)
  print(len(enc['input_ids']))
  print('AAAAAAAAAAAAAAAAA')
  for e in enc['input_ids']:
    print(len(e))

  trainer = Trainer(
      model=model,
      args=args,
      train_dataset=enc,
      data_collator=collator,
  )

  trainer.train()
  trainer.save_model(model_name_dapt)
  tokenizer.save_pretrained(model_name_dapt)

  input('.....')

  return model_name_dapt

def pretrain_model(model_name, trainDf, train_data, databaseToBertDataset):

    tokenizer = databaseToBertDataset.tokenizer

    # 1) Build texts (add a separator like newline so fields don’t merge words)
    texts = (
        trainDf["email"].fillna("").astype(str)
        + "\n"
        + trainDf["bill"].fillna("").astype(str)
    ).tolist()

    ds = datasets.Dataset.from_dict({"text": texts})

    # 2) Tokenize (overflow creates multiple chunks per text)
    def tok(batch):
        return tokenizer(
            batch["text"],
            truncation=True,
            max_length=databaseToBertDataset.maxTokensLength,
            return_overflowing_tokens=True,
            stride=128,
            padding=False,  # IMPORTANT: pad later in collator
        )

    ds_tok = ds.map(tok, batched=True, remove_columns=["text"])

    # 3) Model + MLM collator
    model = AutoModelForMaskedLM.from_pretrained(model_name)
    collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer,
        mlm=True,
        mlm_probability=0.15
    )

    args = TrainingArguments(
        output_dir=f"{model_name}_dapt",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=2,
        learning_rate=5e-5,
        weight_decay=0.01,
        warmup_ratio=0.06,
        num_train_epochs=2,
        fp16=True,
        logging_steps=100,
        save_steps=1000,
        save_total_limit=2,
        report_to="none",
    )

    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=ds_tok,     # ✅ TRAIN ON TOKENIZED DATASET
        data_collator=collator,
    )

    trainer.train()
    trainer.save_model(f"{model_name}_dapt")
    tokenizer.save_pretrained(f"{model_name}_dapt")

    model = AutoModel.from_pretrained(f"{model_name}_dapt")

    return model

# %%
set_seed(42)

HIERACHICAL_TRANSFORMER = 'HIERACHICAL_TRANSFORMER'
HIERACHICAL_TRANSFORMERV2 = 'HIERACHICAL_TRANSFORMERV2'
HIERACHICAL_TRANSFORMER_LSAN = 'HIERACHICAL_TRANSFORMER_LSAN'
HIERACHICAL_TRANSFORMER_LSAN_DEP = 'HIERACHICAL_TRANSFORMER_LSAN_DEP'
HIERACHICAL_GRU = 'HIERACHICAL_GRU'


gc.collect()
torch.cuda.empty_cache()

# Read data
df = pd.read_csv('data.csv')
df['bills'].fillna('', inplace=True)
df = df.rename(columns={"emails": "email", "bills": "bill"})
df['labels'] = df['labels'].apply(lambda x: x.replace(' ', '').replace(',', '|') if isinstance(x, str) else [])


# Train/val/test split
trainRatio = 0.7
valRatio = 0.25
testRatio = 0.05
trainDf, valTestDf = train_test_split(df, train_size=trainRatio, random_state=42)
relativeRatio = valRatio/(valRatio + testRatio)
valDf, testDf = train_test_split(valTestDf, train_size=relativeRatio, random_state=42)

trainDf = trainDf.reset_index()
valDf = valDf.reset_index()
testDf = testDf.reset_index()

# === CONFIG ===
MODEL_NAME_BERT =  CAMEMBERT # ROBERTA # DISTIL_CAMEMBERT # CAMEMBERT # BERT
MODEL_NAME = HIERACHICAL_TRANSFORMER_LSAN_DEP # HIERACHICAL_TRANSFORMER # HIERACHICAL_TRANSFORMERV2 # HIERACHICAL_TRANSFORMER_LSAN # HIERACHICAL_TRANSFORMER_LSAN_DEP # HIERACHICAL_GRU
PRETRAIN = True

epochs = 250
batch_size = 4
threshold = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'CONFIG: batch_size={batch_size}, epochs={epochs}, device={device}')
print('')


# === Eval Variables ===
evalMetrics = init_eval_metrics()

# === Tokenize ===
databaseToBertDataset = DatabaseToBertDataset(model_name=MODEL_NAME_BERT)
train_data, train_labels, labels_list = databaseToBertDataset.execute(trainDf)
val_data, val_labels, _ = databaseToBertDataset.execute(valDf)

# === Pretrain ===
model_dapt = None
if PRETRAIN:
  model_dapt = pretrain_model(MODEL_NAME_BERT, trainDf, train_data, databaseToBertDataset)


if MODEL_NAME_BERT == BERT:
    # === Datasets ===
    train_dataset = TokenizedDataset(
        train_data,
        train_labels
    )
    val_dataset = TokenizedDataset(
        val_data,
        val_labels
    )

    # === Model ===
    model = BertHierachicalClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

elif MODEL_NAME_BERT == CAMEMBERT or MODEL_NAME_BERT == DISTIL_CAMEMBERT or MODEL_NAME_BERT == ROBERTA:

    # === Datasets ===
    train_dataset = TokenizedDatasetNoType(
        train_data,
        train_labels
    )
    val_dataset = TokenizedDatasetNoType(
        val_data,
        val_labels
    )

    # === Model ===
    if MODEL_NAME == HIERACHICAL_TRANSFORMER:
        model = CamembertHierachicalClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))
    elif MODEL_NAME == HIERACHICAL_TRANSFORMERV2:
        model = CamembertHierachicalClassifierV2(MODEL_NAME_BERT, num_labels=len(labels_list))
    elif MODEL_NAME == HIERACHICAL_TRANSFORMER_LSAN:
        model = CamembertHierachicalLsanClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))
    elif MODEL_NAME == HIERACHICAL_TRANSFORMER_LSAN_DEP:
        model = CamembertHierachicalLsanClassifierDep(MODEL_NAME_BERT, num_labels=len(labels_list), model_dapt=model_dapt, drop_out=0.3180700697510773, d_a=32)
    elif MODEL_NAME == HIERACHICAL_GRU:
        model = CamembertHierarchicalGRUClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

elif MODEL_NAME_BERT == LONGFORMER:

    # === Datasets ===
    train_dataset = TensorDataset(
        train_data["input_ids"],
        train_data["attention_mask"],
        train_data["labels"].float()
    )
    val_dataset = TensorDataset(
        val_data["input_ids"],
        val_data["attention_mask"],
        val_data["labels"].float()
    )

    # === Model ===
    model = LongformerClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

elif MODEL_NAME_BERT == BIGBIRD:

    # === Datasets ===
    train_dataset = TensorDataset(
        train_data["input_ids"],
        train_data["attention_mask"],
        train_data["labels"].float()
    )
    val_dataset = TensorDataset(
        val_data["input_ids"],
        val_data["attention_mask"],
        val_data["labels"].float()
    )

    # === Model ===
    model = BigbirdClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))


train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True,
          collate_fn=(lambda batch: train_dataset.collateFunc(batch, databaseToBertDataset.tokenizer.pad_token_id)))

val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False,
          collate_fn=(lambda batch: val_dataset.collateFunc(batch, databaseToBertDataset.tokenizer.pad_token_id)))

model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=4.078884431363121e-05, weight_decay=0.058072588932673724) # lr=2e-5
criterion = nn.BCEWithLogitsLoss()
trainLosses = []
evalLosses = []

# === TRAINING LOOP ===
for epoch in range(epochs):
    model.train()

    sumLoss = 0.0
    for batch_idx, batch in enumerate(train_loader):
        batch = [t.to(device, non_blocking=True) for t in batch]

        xTensor = batch[:-1]
        labels = batch[-1]

        optimizer.zero_grad()

        # Forward
        outputs = model(xTensor)

        # Compute loss
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        sumLoss += loss.item()
        sys.stdout.write(f"\rEpoch {epoch+1}/{epochs}, Batch {batch_idx+1}/{len(train_loader)} - Loss: {loss.item():.4f}")
        sys.stdout.flush()

    meanLoss = sumLoss / len(train_loader)
    trainLosses.append(meanLoss)
    sys.stdout.write(f"\rEpoch {epoch+1}/{epochs}, Batch {len(train_loader)}/{len(train_loader)} - Loss: {meanLoss:.4f}")
    sys.stdout.flush()

    # === EVALUATION LOOP ===
    model.eval()
    sumLossVal = 0.0
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in val_loader:
            batch = [t.to(device, non_blocking=True) for t in batch]
            xTensor = batch[:-1]
            labels = batch[-1]

            outputs = model(xTensor)

            loss = criterion(outputs, labels)


            # --- Predictions ---
            preds = torch.sigmoid(outputs) > threshold  # (batch_size, num_labels)

            # Move to CPU for sklearn
            all_labels.append(labels.cpu().numpy())
            all_preds.append(preds.cpu().numpy())

            sumLossVal += loss.item()

    meanLossVal = sumLoss / len(val_loader)
    evalLosses.append(meanLossVal)

    # === Combine batches ===
    all_labels = np.concatenate(all_labels, axis=0)
    all_preds = np.concatenate(all_preds, axis=0)

    # === Metrics ===
    avg_eval_loss = sum(evalLosses) / len(evalLosses)
    evalMetric = compute_eval_metrics(avg_eval_loss, all_labels, all_preds, labels_list)
    print_eval_metrics(evalMetric)

save_eval_metrics(evalMetrics, evalMetric)
# print_eval_metrics(evalMetrics)
# Out:
# /tmp/ipython-input-3727465847.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bills'].fillna('', inplace=True)
# /tmp/ipython-input-3727465847.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['bills'].fillna('', inplace=True)
# CONFIG: batch_size=4, epochs=250, device=cuda
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# CamembertForMaskedLM LOAD REPORT from: camembert-base
# Key                         | Status     |
# ----------------------------+------------+-
# roberta.pooler.dense.weight | UNEXPECTED |
# roberta.pooler.dense.bias   | UNEXPECTED |
# lm_head.decoder.weight      | MISSING    |
# lm_head.decoder.bias        | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='70' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [70/70 00:16, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# CamembertModel LOAD REPORT from: camembert-base_dapt
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.decoder.bias      | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# lm_head.decoder.weight    | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# pooler.dense.bias         | MISSING    |
# pooler.dense.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Init model CamembertHierachicalLsanClassifierDep(model_dapt=<class 'transformers.models.camembert.modeling_camembert.CamembertModel'>, model_name=camembert-base, num_labels=11, d_a=32, drop_out=0.3180700697510773 freeze_bert=False)
# Epoch 1/250, Batch 27/27 - Loss: 0.5719  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 2/250, Batch 27/27 - Loss: 0.5228  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 3/250, Batch 27/27 - Loss: 0.5187  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 4/250, Batch 27/27 - Loss: 0.5142  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 5/250, Batch 27/27 - Loss: 0.5068  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 6/250, Batch 27/27 - Loss: 0.5137  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 7/250, Batch 27/27 - Loss: 0.5099  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 8/250, Batch 27/27 - Loss: 0.4966  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000
# Epoch 9/250, Batch 27/27 - Loss: 0.4764  Accuracy: 0.0000 F1-Micro: 0.1212 F1-Macro-Avg 0.1028 Precision: 0.6667 Recall: 0.0667
# Epoch 10/250, Batch 27/27 - Loss: 0.4444  Accuracy: 0.0000 F1-Micro: 0.2759 F1-Macro-Avg 0.2194 Precision: 0.6154 Recall: 0.1778
# Epoch 11/250, Batch 27/27 - Loss: 0.4135  Accuracy: 0.0000 F1-Micro: 0.3590 F1-Macro-Avg 0.2995 Precision: 0.7778 Recall: 0.2333
# Epoch 12/250, Batch 27/27 - Loss: 0.3783  Accuracy: 0.0000 F1-Micro: 0.3667 F1-Macro-Avg 0.2929 Precision: 0.7333 Recall: 0.2444
# Epoch 13/250, Batch 27/27 - Loss: 0.3498  Accuracy: 0.1622 F1-Micro: 0.5468 F1-Macro-Avg 0.4718 Precision: 0.7755 Recall: 0.4222
# Epoch 14/250, Batch 27/27 - Loss: 0.3328  Accuracy: 0.1622 F1-Micro: 0.5571 F1-Macro-Avg 0.5197 Precision: 0.7800 Recall: 0.4333
# Epoch 15/250, Batch 27/27 - Loss: 0.3086  Accuracy: 0.2162 F1-Micro: 0.6475 F1-Macro-Avg 0.5967 Precision: 0.9184 Recall: 0.5000
# Epoch 16/250, Batch 27/27 - Loss: 0.2768  Accuracy: 0.2162 F1-Micro: 0.6154 F1-Macro-Avg 0.5493 Precision: 0.8302 Recall: 0.4889
# Epoch 17/250, Batch 27/27 - Loss: 0.2572  Accuracy: 0.2703 F1-Micro: 0.6620 F1-Macro-Avg 0.6154 Precision: 0.9038 Recall: 0.5222
# Epoch 18/250, Batch 27/27 - Loss: 0.2534  Accuracy: 0.2432 F1-Micro: 0.5985 F1-Macro-Avg 0.5430 Precision: 0.8723 Recall: 0.4556
# Epoch 19/250, Batch 27/27 - Loss: 0.2160  Accuracy: 0.2162 F1-Micro: 0.7200 F1-Macro-Avg 0.7039 Precision: 0.9000 Recall: 0.6000
# Epoch 20/250, Batch 27/27 - Loss: 0.1892  Accuracy: 0.3514 F1-Micro: 0.7484 F1-Macro-Avg 0.7397 Precision: 0.8923 Recall: 0.6444
# Epoch 21/250, Batch 27/27 - Loss: 0.1722  Accuracy: 0.4054 F1-Micro: 0.7750 F1-Macro-Avg 0.7771 Precision: 0.8857 Recall: 0.6889
# Epoch 22/250, Batch 27/27 - Loss: 0.1490  Accuracy: 0.4054 F1-Micro: 0.7875 F1-Macro-Avg 0.7913 Precision: 0.9000 Recall: 0.7000
# Epoch 23/250, Batch 27/27 - Loss: 0.1238  Accuracy: 0.4595 F1-Micro: 0.8125 F1-Macro-Avg 0.8078 Precision: 0.9286 Recall: 0.7222
# Epoch 24/250, Batch 27/27 - Loss: 0.1140  Accuracy: 0.5135 F1-Micro: 0.8293 F1-Macro-Avg 0.8339 Precision: 0.9189 Recall: 0.7556
# Epoch 25/250, Batch 27/27 - Loss: 0.1109  Accuracy: 0.5676 F1-Micro: 0.8521 F1-Macro-Avg 0.8503 Precision: 0.9114 Recall: 0.8000
# Epoch 26/250, Batch 27/27 - Loss: 0.0998  Accuracy: 0.4595 F1-Micro: 0.8323 F1-Macro-Avg 0.8190 Precision: 0.9437 Recall: 0.7444
# Epoch 27/250, Batch 27/27 - Loss: 0.0918  Accuracy: 0.5135 F1-Micro: 0.8272 F1-Macro-Avg 0.8232 Precision: 0.9306 Recall: 0.7444
# Epoch 28/250, Batch 27/27 - Loss: 0.0824  Accuracy: 0.5946 F1-Micro: 0.8375 F1-Macro-Avg 0.8434 Precision: 0.9571 Recall: 0.7444
# Epoch 29/250, Batch 27/27 - Loss: 0.0764  Accuracy: 0.6757 F1-Micro: 0.8837 F1-Macro-Avg 0.8771 Precision: 0.9268 Recall: 0.8444
# Epoch 30/250, Batch 27/27 - Loss: 0.0674  Accuracy: 0.6486 F1-Micro: 0.9070 F1-Macro-Avg 0.9099 Precision: 0.9512 Recall: 0.8667
# Epoch 31/250, Batch 27/27 - Loss: 0.0632  Accuracy: 0.6486 F1-Micro: 0.8837 F1-Macro-Avg 0.8894 Precision: 0.9268 Recall: 0.8444
# Epoch 32/250, Batch 27/27 - Loss: 0.0578  Accuracy: 0.5676 F1-Micro: 0.8503 F1-Macro-Avg 0.8515 Precision: 0.9221 Recall: 0.7889
# Epoch 33/250, Batch 27/27 - Loss: 0.0527  Accuracy: 0.5405 F1-Micro: 0.8690 F1-Macro-Avg 0.8736 Precision: 0.9359 Recall: 0.8111
# Epoch 34/250, Batch 27/27 - Loss: 0.0469  Accuracy: 0.6216 F1-Micro: 0.8757 F1-Macro-Avg 0.8722 Precision: 0.9367 Recall: 0.8222
# Epoch 35/250, Batch 27/27 - Loss: 0.0489  Accuracy: 0.6216 F1-Micro: 0.8606 F1-Macro-Avg 0.8611 Precision: 0.9467 Recall: 0.7889
# Epoch 36/250, Batch 27/27 - Loss: 0.0522  Accuracy: 0.5946 F1-Micro: 0.8814 F1-Macro-Avg 0.8794 Precision: 0.8966 Recall: 0.8667
# Epoch 37/250, Batch 27/27 - Loss: 0.0435  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8971 Precision: 0.9286 Recall: 0.8667
# Epoch 38/250, Batch 27/27 - Loss: 0.0407  Accuracy: 0.5946 F1-Micro: 0.8639 F1-Macro-Avg 0.8623 Precision: 0.9241 Recall: 0.8111
# Epoch 39/250, Batch 27/27 - Loss: 0.0397  Accuracy: 0.5946 F1-Micro: 0.8772 F1-Macro-Avg 0.8819 Precision: 0.9259 Recall: 0.8333
# Epoch 40/250, Batch 27/27 - Loss: 0.0413  Accuracy: 0.5676 F1-Micro: 0.8571 F1-Macro-Avg 0.8540 Precision: 0.9231 Recall: 0.8000
# Epoch 41/250, Batch 27/27 - Loss: 0.0376  Accuracy: 0.6216 F1-Micro: 0.8824 F1-Macro-Avg 0.8759 Precision: 0.9375 Recall: 0.8333
# Epoch 42/250, Batch 27/27 - Loss: 0.0348  Accuracy: 0.6486 F1-Micro: 0.8862 F1-Macro-Avg 0.8922 Precision: 0.9610 Recall: 0.8222
# Epoch 43/250, Batch 27/27 - Loss: 0.0335  Accuracy: 0.6757 F1-Micro: 0.9006 F1-Macro-Avg 0.9057 Precision: 0.9506 Recall: 0.8556
# Epoch 44/250, Batch 27/27 - Loss: 0.0327  Accuracy: 0.6486 F1-Micro: 0.8889 F1-Macro-Avg 0.8932 Precision: 0.9383 Recall: 0.8444
# Epoch 45/250, Batch 27/27 - Loss: 0.0329  Accuracy: 0.6757 F1-Micro: 0.9205 F1-Macro-Avg 0.9266 Precision: 0.9419 Recall: 0.9000
# Epoch 46/250, Batch 27/27 - Loss: 0.0354  Accuracy: 0.6486 F1-Micro: 0.8434 F1-Macro-Avg 0.8421 Precision: 0.9211 Recall: 0.7778
# Epoch 47/250, Batch 27/27 - Loss: 0.0335  Accuracy: 0.5946 F1-Micro: 0.8824 F1-Macro-Avg 0.8731 Precision: 0.9375 Recall: 0.8333
# Epoch 48/250, Batch 27/27 - Loss: 0.0299  Accuracy: 0.7838 F1-Micro: 0.9266 F1-Macro-Avg 0.9253 Precision: 0.9425 Recall: 0.9111
# Epoch 49/250, Batch 27/27 - Loss: 0.0287  Accuracy: 0.5946 F1-Micro: 0.8757 F1-Macro-Avg 0.8799 Precision: 0.9367 Recall: 0.8222
# Epoch 50/250, Batch 27/27 - Loss: 0.0260  Accuracy: 0.6486 F1-Micro: 0.9080 F1-Macro-Avg 0.9058 Precision: 0.9405 Recall: 0.8778
# Epoch 51/250, Batch 27/27 - Loss: 0.0241  Accuracy: 0.5676 F1-Micro: 0.8862 F1-Macro-Avg 0.8951 Precision: 0.9610 Recall: 0.8222
# Epoch 52/250, Batch 27/27 - Loss: 0.0216  Accuracy: 0.6757 F1-Micro: 0.8862 F1-Macro-Avg 0.8844 Precision: 0.9610 Recall: 0.8222
# Epoch 53/250, Batch 27/27 - Loss: 0.0223  Accuracy: 0.6216 F1-Micro: 0.8876 F1-Macro-Avg 0.8903 Precision: 0.9494 Recall: 0.8333
# Epoch 54/250, Batch 27/27 - Loss: 0.0220  Accuracy: 0.5676 F1-Micro: 0.8606 F1-Macro-Avg 0.8614 Precision: 0.9467 Recall: 0.7889
# Epoch 55/250, Batch 27/27 - Loss: 0.0244  Accuracy: 0.6757 F1-Micro: 0.9123 F1-Macro-Avg 0.9150 Precision: 0.9630 Recall: 0.8667
# Epoch 56/250, Batch 27/27 - Loss: 0.0241  Accuracy: 0.5676 F1-Micro: 0.8757 F1-Macro-Avg 0.8744 Precision: 0.9367 Recall: 0.8222
# Epoch 57/250, Batch 27/27 - Loss: 0.0211  Accuracy: 0.6486 F1-Micro: 0.9143 F1-Macro-Avg 0.9147 Precision: 0.9412 Recall: 0.8889
# Epoch 58/250, Batch 27/27 - Loss: 0.0185  Accuracy: 0.6486 F1-Micro: 0.9061 F1-Macro-Avg 0.9057 Precision: 0.9011 Recall: 0.9111
# Epoch 59/250, Batch 27/27 - Loss: 0.0188  Accuracy: 0.7297 F1-Micro: 0.9205 F1-Macro-Avg 0.9173 Precision: 0.9419 Recall: 0.9000
# Epoch 60/250, Batch 27/27 - Loss: 0.0182  Accuracy: 0.6757 F1-Micro: 0.9143 F1-Macro-Avg 0.9059 Precision: 0.9412 Recall: 0.8889
# Epoch 61/250, Batch 27/27 - Loss: 0.0177  Accuracy: 0.6486 F1-Micro: 0.9091 F1-Macro-Avg 0.9121 Precision: 0.9302 Recall: 0.8889
# Epoch 62/250, Batch 27/27 - Loss: 0.0169  Accuracy: 0.6757 F1-Micro: 0.9040 F1-Macro-Avg 0.9150 Precision: 0.9195 Recall: 0.8889
# Epoch 63/250, Batch 27/27 - Loss: 0.0242  Accuracy: 0.4865 F1-Micro: 0.8571 F1-Macro-Avg 0.8534 Precision: 0.9231 Recall: 0.8000
# Epoch 64/250, Batch 27/27 - Loss: 0.0248  Accuracy: 0.6486 F1-Micro: 0.8800 F1-Macro-Avg 0.8850 Precision: 0.9059 Recall: 0.8556
# Epoch 65/250, Batch 27/27 - Loss: 0.0220  Accuracy: 0.6216 F1-Micro: 0.8824 F1-Macro-Avg 0.8923 Precision: 0.9375 Recall: 0.8333
# Epoch 66/250, Batch 27/27 - Loss: 0.0190  Accuracy: 0.5946 F1-Micro: 0.8772 F1-Macro-Avg 0.8782 Precision: 0.9259 Recall: 0.8333
# Epoch 67/250, Batch 27/27 - Loss: 0.0170  Accuracy: 0.6757 F1-Micro: 0.9080 F1-Macro-Avg 0.9049 Precision: 0.9405 Recall: 0.8778
# Epoch 68/250, Batch 27/27 - Loss: 0.0171  Accuracy: 0.5405 F1-Micro: 0.8503 F1-Macro-Avg 0.8489 Precision: 0.9221 Recall: 0.7889
# Epoch 69/250, Batch 27/27 - Loss: 0.0187  Accuracy: 0.6486 F1-Micro: 0.8837 F1-Macro-Avg 0.8858 Precision: 0.9268 Recall: 0.8444
# Epoch 70/250, Batch 27/27 - Loss: 0.0234  Accuracy: 0.5405 F1-Micro: 0.8605 F1-Macro-Avg 0.8569 Precision: 0.9024 Recall: 0.8222
# Epoch 71/250, Batch 27/27 - Loss: 0.0173  Accuracy: 0.6757 F1-Micro: 0.8994 F1-Macro-Avg 0.9036 Precision: 0.9620 Recall: 0.8444
# Epoch 72/250, Batch 27/27 - Loss: 0.0156  Accuracy: 0.6757 F1-Micro: 0.8994 F1-Macro-Avg 0.9040 Precision: 0.9620 Recall: 0.8444
# Epoch 73/250, Batch 27/27 - Loss: 0.0132  Accuracy: 0.7297 F1-Micro: 0.9017 F1-Macro-Avg 0.9012 Precision: 0.9398 Recall: 0.8667
# Epoch 74/250, Batch 27/27 - Loss: 0.0131  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9247 Precision: 0.9412 Recall: 0.8889
# Epoch 75/250, Batch 27/27 - Loss: 0.0130  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9117 Precision: 0.9405 Recall: 0.8778
# Epoch 76/250, Batch 27/27 - Loss: 0.0109  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8910 Precision: 0.9167 Recall: 0.8556
# Epoch 77/250, Batch 27/27 - Loss: 0.0108  Accuracy: 0.6486 F1-Micro: 0.9070 F1-Macro-Avg 0.9143 Precision: 0.9512 Recall: 0.8667
# Epoch 78/250, Batch 27/27 - Loss: 0.0101  Accuracy: 0.7027 F1-Micro: 0.8941 F1-Macro-Avg 0.9033 Precision: 0.9500 Recall: 0.8444
# Epoch 79/250, Batch 27/27 - Loss: 0.0092  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.8990 Precision: 0.9286 Recall: 0.8667
# Epoch 80/250, Batch 27/27 - Loss: 0.0105  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.9029 Precision: 0.9390 Recall: 0.8556
# Epoch 81/250, Batch 27/27 - Loss: 0.0115  Accuracy: 0.6757 F1-Micro: 0.8941 F1-Macro-Avg 0.8963 Precision: 0.9500 Recall: 0.8444
# Epoch 82/250, Batch 27/27 - Loss: 0.0109  Accuracy: 0.6757 F1-Micro: 0.9059 F1-Macro-Avg 0.9054 Precision: 0.9625 Recall: 0.8556
# Epoch 83/250, Batch 27/27 - Loss: 0.0090  Accuracy: 0.7027 F1-Micro: 0.9017 F1-Macro-Avg 0.9075 Precision: 0.9398 Recall: 0.8667
# Epoch 84/250, Batch 27/27 - Loss: 0.0090  Accuracy: 0.7027 F1-Micro: 0.9091 F1-Macro-Avg 0.9096 Precision: 0.9302 Recall: 0.8889
# Epoch 85/250, Batch 27/27 - Loss: 0.0070  Accuracy: 0.7027 F1-Micro: 0.8914 F1-Macro-Avg 0.8925 Precision: 0.9176 Recall: 0.8667
# Epoch 86/250, Batch 27/27 - Loss: 0.0075  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9057 Precision: 0.9294 Recall: 0.8778
# Epoch 87/250, Batch 27/27 - Loss: 0.0061  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9058 Precision: 0.9294 Recall: 0.8778
# Epoch 88/250, Batch 27/27 - Loss: 0.0062  Accuracy: 0.7568 F1-Micro: 0.9205 F1-Macro-Avg 0.9251 Precision: 0.9419 Recall: 0.9000
# Epoch 89/250, Batch 27/27 - Loss: 0.0064  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8998 Precision: 0.9286 Recall: 0.8667
# Epoch 90/250, Batch 27/27 - Loss: 0.0058  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.8977 Precision: 0.9286 Recall: 0.8667
# Epoch 91/250, Batch 27/27 - Loss: 0.0052  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9081 Precision: 0.9294 Recall: 0.8778
# Epoch 92/250, Batch 27/27 - Loss: 0.0051  Accuracy: 0.7027 F1-Micro: 0.9153 F1-Macro-Avg 0.9179 Precision: 0.9310 Recall: 0.9000
# Epoch 93/250, Batch 27/27 - Loss: 0.0055  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.9017 Precision: 0.9286 Recall: 0.8667
# Epoch 94/250, Batch 27/27 - Loss: 0.0048  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.9001 Precision: 0.9286 Recall: 0.8667
# Epoch 95/250, Batch 27/27 - Loss: 0.0052  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.9017 Precision: 0.9286 Recall: 0.8667
# Epoch 96/250, Batch 27/27 - Loss: 0.0056  Accuracy: 0.7027 F1-Micro: 0.9040 F1-Macro-Avg 0.9086 Precision: 0.9195 Recall: 0.8889
# Epoch 97/250, Batch 27/27 - Loss: 0.0050  Accuracy: 0.7027 F1-Micro: 0.9091 F1-Macro-Avg 0.9140 Precision: 0.9302 Recall: 0.8889
# Epoch 98/250, Batch 27/27 - Loss: 0.0051  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9216 Precision: 0.9412 Recall: 0.8889
# Epoch 99/250, Batch 27/27 - Loss: 0.0052  Accuracy: 0.6216 F1-Micro: 0.9017 F1-Macro-Avg 0.9053 Precision: 0.9398 Recall: 0.8667
# Epoch 100/250, Batch 27/27 - Loss: 0.0044  Accuracy: 0.7027 F1-Micro: 0.9080 F1-Macro-Avg 0.9098 Precision: 0.9405 Recall: 0.8778
# Epoch 101/250, Batch 27/27 - Loss: 0.0059  Accuracy: 0.7568 F1-Micro: 0.9213 F1-Macro-Avg 0.9265 Precision: 0.9318 Recall: 0.9111
# Epoch 102/250, Batch 27/27 - Loss: 0.0075  Accuracy: 0.6486 F1-Micro: 0.8889 F1-Macro-Avg 0.8869 Precision: 0.9383 Recall: 0.8444
# Epoch 103/250, Batch 27/27 - Loss: 0.0484  Accuracy: 0.5676 F1-Micro: 0.8602 F1-Macro-Avg 0.8599 Precision: 0.8333 Recall: 0.8889
# Epoch 104/250, Batch 27/27 - Loss: 0.0462  Accuracy: 0.5405 F1-Micro: 0.8471 F1-Macro-Avg 0.8402 Precision: 0.9000 Recall: 0.8000
# Epoch 105/250, Batch 27/27 - Loss: 0.0645  Accuracy: 0.5405 F1-Micro: 0.8589 F1-Macro-Avg 0.8546 Precision: 0.9589 Recall: 0.7778
# Epoch 106/250, Batch 27/27 - Loss: 0.0585  Accuracy: 0.4865 F1-Micro: 0.8690 F1-Macro-Avg 0.8531 Precision: 0.9359 Recall: 0.8111
# Epoch 107/250, Batch 27/27 - Loss: 0.0422  Accuracy: 0.6486 F1-Micro: 0.8876 F1-Macro-Avg 0.8873 Precision: 0.8977 Recall: 0.8778
# Epoch 108/250, Batch 27/27 - Loss: 0.0422  Accuracy: 0.5676 F1-Micro: 0.8652 F1-Macro-Avg 0.8667 Precision: 0.8750 Recall: 0.8556
# Epoch 109/250, Batch 27/27 - Loss: 0.0332  Accuracy: 0.6486 F1-Micro: 0.8810 F1-Macro-Avg 0.8865 Precision: 0.9487 Recall: 0.8222
# Epoch 110/250, Batch 27/27 - Loss: 0.0308  Accuracy: 0.5676 F1-Micro: 0.8623 F1-Macro-Avg 0.8623 Precision: 0.9351 Recall: 0.8000
# Epoch 111/250, Batch 27/27 - Loss: 0.0225  Accuracy: 0.6486 F1-Micro: 0.8810 F1-Macro-Avg 0.8784 Precision: 0.9487 Recall: 0.8222
# Epoch 112/250, Batch 27/27 - Loss: 0.0133  Accuracy: 0.7027 F1-Micro: 0.8953 F1-Macro-Avg 0.9000 Precision: 0.9390 Recall: 0.8556
# Epoch 113/250, Batch 27/27 - Loss: 0.0098  Accuracy: 0.6757 F1-Micro: 0.8810 F1-Macro-Avg 0.8806 Precision: 0.9487 Recall: 0.8222
# Epoch 114/250, Batch 27/27 - Loss: 0.0056  Accuracy: 0.7568 F1-Micro: 0.9080 F1-Macro-Avg 0.9108 Precision: 0.9405 Recall: 0.8778
# Epoch 115/250, Batch 27/27 - Loss: 0.0055  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9177 Precision: 0.9518 Recall: 0.8778
# Epoch 116/250, Batch 27/27 - Loss: 0.0048  Accuracy: 0.6757 F1-Micro: 0.8941 F1-Macro-Avg 0.8913 Precision: 0.9500 Recall: 0.8444
# Epoch 117/250, Batch 27/27 - Loss: 0.0043  Accuracy: 0.7027 F1-Micro: 0.8941 F1-Macro-Avg 0.8936 Precision: 0.9500 Recall: 0.8444
# Epoch 118/250, Batch 27/27 - Loss: 0.0042  Accuracy: 0.7568 F1-Micro: 0.9195 F1-Macro-Avg 0.9216 Precision: 0.9524 Recall: 0.8889
# Epoch 119/250, Batch 27/27 - Loss: 0.0041  Accuracy: 0.7568 F1-Micro: 0.9133 F1-Macro-Avg 0.9177 Precision: 0.9518 Recall: 0.8778
# Epoch 120/250, Batch 27/27 - Loss: 0.0040  Accuracy: 0.7568 F1-Micro: 0.9195 F1-Macro-Avg 0.9216 Precision: 0.9524 Recall: 0.8889
# Epoch 121/250, Batch 27/27 - Loss: 0.0037  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9074 Precision: 0.9405 Recall: 0.8778
# Epoch 122/250, Batch 27/27 - Loss: 0.0036  Accuracy: 0.7838 F1-Micro: 0.9257 F1-Macro-Avg 0.9262 Precision: 0.9529 Recall: 0.9000
# Epoch 123/250, Batch 27/27 - Loss: 0.0034  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9117 Precision: 0.9518 Recall: 0.8778
# Epoch 124/250, Batch 27/27 - Loss: 0.0031  Accuracy: 0.7838 F1-Micro: 0.9257 F1-Macro-Avg 0.9298 Precision: 0.9529 Recall: 0.9000
# Epoch 125/250, Batch 27/27 - Loss: 0.0037  Accuracy: 0.7297 F1-Micro: 0.9195 F1-Macro-Avg 0.9199 Precision: 0.9524 Recall: 0.8889
# Epoch 126/250, Batch 27/27 - Loss: 0.0033  Accuracy: 0.7568 F1-Micro: 0.9133 F1-Macro-Avg 0.9159 Precision: 0.9518 Recall: 0.8778
# Epoch 127/250, Batch 27/27 - Loss: 0.0031  Accuracy: 0.7568 F1-Micro: 0.9257 F1-Macro-Avg 0.9298 Precision: 0.9529 Recall: 0.9000
# Epoch 128/250, Batch 27/27 - Loss: 0.0033  Accuracy: 0.7297 F1-Micro: 0.9070 F1-Macro-Avg 0.9077 Precision: 0.9512 Recall: 0.8667
# Epoch 129/250, Batch 27/27 - Loss: 0.0033  Accuracy: 0.7027 F1-Micro: 0.9006 F1-Macro-Avg 0.9018 Precision: 0.9506 Recall: 0.8556
# Epoch 130/250, Batch 27/27 - Loss: 0.0037  Accuracy: 0.6757 F1-Micro: 0.8953 F1-Macro-Avg 0.8933 Precision: 0.9390 Recall: 0.8556
# Epoch 131/250, Batch 27/27 - Loss: 0.0033  Accuracy: 0.6757 F1-Micro: 0.8941 F1-Macro-Avg 0.8975 Precision: 0.9500 Recall: 0.8444
# Epoch 132/250, Batch 27/27 - Loss: 0.0049  Accuracy: 0.6757 F1-Micro: 0.9006 F1-Macro-Avg 0.8975 Precision: 0.9506 Recall: 0.8556
# Epoch 133/250, Batch 27/27 - Loss: 0.0039  Accuracy: 0.7027 F1-Micro: 0.9070 F1-Macro-Avg 0.9058 Precision: 0.9512 Recall: 0.8667
# Epoch 134/250, Batch 27/27 - Loss: 0.0037  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9037 Precision: 0.9294 Recall: 0.8778
# Epoch 135/250, Batch 27/27 - Loss: 0.0030  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9014 Precision: 0.9294 Recall: 0.8778
# Epoch 136/250, Batch 27/27 - Loss: 0.0035  Accuracy: 0.7568 F1-Micro: 0.9143 F1-Macro-Avg 0.9174 Precision: 0.9412 Recall: 0.8889
# Epoch 137/250, Batch 27/27 - Loss: 0.0026  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9133 Precision: 0.9518 Recall: 0.8778
# Epoch 138/250, Batch 27/27 - Loss: 0.0039  Accuracy: 0.7297 F1-Micro: 0.9195 F1-Macro-Avg 0.9238 Precision: 0.9524 Recall: 0.8889
# Epoch 139/250, Batch 27/27 - Loss: 0.0038  Accuracy: 0.7838 F1-Micro: 0.9326 F1-Macro-Avg 0.9352 Precision: 0.9432 Recall: 0.9222
# Epoch 140/250, Batch 27/27 - Loss: 0.0037  Accuracy: 0.6757 F1-Micro: 0.9070 F1-Macro-Avg 0.9156 Precision: 0.9512 Recall: 0.8667
# Epoch 141/250, Batch 27/27 - Loss: 0.0028  Accuracy: 0.7838 F1-Micro: 0.9257 F1-Macro-Avg 0.9298 Precision: 0.9529 Recall: 0.9000
# Epoch 142/250, Batch 27/27 - Loss: 0.0027  Accuracy: 0.7568 F1-Micro: 0.9205 F1-Macro-Avg 0.9255 Precision: 0.9419 Recall: 0.9000
# Epoch 143/250, Batch 27/27 - Loss: 0.0036  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9139 Precision: 0.9405 Recall: 0.8778
# Epoch 144/250, Batch 27/27 - Loss: 0.0051  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9081 Precision: 0.9294 Recall: 0.8778
# Epoch 145/250, Batch 27/27 - Loss: 0.0043  Accuracy: 0.6757 F1-Micro: 0.9123 F1-Macro-Avg 0.9139 Precision: 0.9630 Recall: 0.8667
# Epoch 146/250, Batch 27/27 - Loss: 0.0048  Accuracy: 0.6486 F1-Micro: 0.8989 F1-Macro-Avg 0.8983 Precision: 0.9091 Recall: 0.8889
# Epoch 147/250, Batch 27/27 - Loss: 0.0058  Accuracy: 0.6486 F1-Micro: 0.8810 F1-Macro-Avg 0.8902 Precision: 0.9487 Recall: 0.8222
# Epoch 148/250, Batch 27/27 - Loss: 0.0097  Accuracy: 0.7027 F1-Micro: 0.8966 F1-Macro-Avg 0.8987 Precision: 0.9286 Recall: 0.8667
# Epoch 149/250, Batch 27/27 - Loss: 0.0091  Accuracy: 0.6757 F1-Micro: 0.9133 F1-Macro-Avg 0.9141 Precision: 0.9518 Recall: 0.8778
# Epoch 150/250, Batch 27/27 - Loss: 0.0056  Accuracy: 0.6757 F1-Micro: 0.9000 F1-Macro-Avg 0.9024 Precision: 0.9000 Recall: 0.9000
# Epoch 151/250, Batch 27/27 - Loss: 0.0038  Accuracy: 0.6216 F1-Micro: 0.8876 F1-Macro-Avg 0.8900 Precision: 0.9494 Recall: 0.8333
# Epoch 152/250, Batch 27/27 - Loss: 0.0041  Accuracy: 0.7027 F1-Micro: 0.9143 F1-Macro-Avg 0.9122 Precision: 0.9412 Recall: 0.8889
# Epoch 153/250, Batch 27/27 - Loss: 0.0034  Accuracy: 0.6757 F1-Micro: 0.9143 F1-Macro-Avg 0.9125 Precision: 0.9412 Recall: 0.8889
# Epoch 154/250, Batch 27/27 - Loss: 0.0026  Accuracy: 0.6486 F1-Micro: 0.9006 F1-Macro-Avg 0.8914 Precision: 0.9506 Recall: 0.8556
# Epoch 155/250, Batch 27/27 - Loss: 0.0024  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9013 Precision: 0.9294 Recall: 0.8778
# Epoch 156/250, Batch 27/27 - Loss: 0.0024  Accuracy: 0.7568 F1-Micro: 0.9249 F1-Macro-Avg 0.9279 Precision: 0.9639 Recall: 0.8889
# Epoch 157/250, Batch 27/27 - Loss: 0.0021  Accuracy: 0.6757 F1-Micro: 0.8953 F1-Macro-Avg 0.8972 Precision: 0.9390 Recall: 0.8556
# Epoch 158/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7568 F1-Micro: 0.9143 F1-Macro-Avg 0.9173 Precision: 0.9412 Recall: 0.8889
# Epoch 159/250, Batch 27/27 - Loss: 0.0019  Accuracy: 0.7027 F1-Micro: 0.9059 F1-Macro-Avg 0.9099 Precision: 0.9625 Recall: 0.8556
# Epoch 160/250, Batch 27/27 - Loss: 0.0028  Accuracy: 0.7838 F1-Micro: 0.9326 F1-Macro-Avg 0.9317 Precision: 0.9432 Recall: 0.9222
# Epoch 161/250, Batch 27/27 - Loss: 0.0021  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9105 Precision: 0.9294 Recall: 0.8778
# Epoch 162/250, Batch 27/27 - Loss: 0.0029  Accuracy: 0.6757 F1-Micro: 0.8889 F1-Macro-Avg 0.8984 Precision: 0.9383 Recall: 0.8444
# Epoch 163/250, Batch 27/27 - Loss: 0.0022  Accuracy: 0.6757 F1-Micro: 0.9091 F1-Macro-Avg 0.9086 Precision: 0.9302 Recall: 0.8889
# Epoch 164/250, Batch 27/27 - Loss: 0.0028  Accuracy: 0.7568 F1-Micro: 0.9257 F1-Macro-Avg 0.9238 Precision: 0.9529 Recall: 0.9000
# Epoch 165/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.6757 F1-Micro: 0.9153 F1-Macro-Avg 0.9176 Precision: 0.9310 Recall: 0.9000
# Epoch 166/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.7838 F1-Micro: 0.9143 F1-Macro-Avg 0.9187 Precision: 0.9412 Recall: 0.8889
# Epoch 167/250, Batch 27/27 - Loss: 0.0028  Accuracy: 0.6757 F1-Micro: 0.9186 F1-Macro-Avg 0.9213 Precision: 0.9634 Recall: 0.8778
# Epoch 168/250, Batch 27/27 - Loss: 0.0219  Accuracy: 0.5405 F1-Micro: 0.8452 F1-Macro-Avg 0.8490 Precision: 0.9103 Recall: 0.7889
# Epoch 169/250, Batch 27/27 - Loss: 0.0528  Accuracy: 0.6486 F1-Micro: 0.8876 F1-Macro-Avg 0.8925 Precision: 0.8977 Recall: 0.8778
# Epoch 170/250, Batch 27/27 - Loss: 0.0708  Accuracy: 0.4595 F1-Micro: 0.8144 F1-Macro-Avg 0.8069 Precision: 0.8831 Recall: 0.7556
# Epoch 171/250, Batch 27/27 - Loss: 0.0565  Accuracy: 0.6486 F1-Micro: 0.8736 F1-Macro-Avg 0.8615 Precision: 0.9048 Recall: 0.8444
# Epoch 172/250, Batch 27/27 - Loss: 0.0344  Accuracy: 0.6216 F1-Micro: 0.8852 F1-Macro-Avg 0.8913 Precision: 0.8710 Recall: 0.9000
# Epoch 173/250, Batch 27/27 - Loss: 0.0252  Accuracy: 0.5676 F1-Micro: 0.8525 F1-Macro-Avg 0.8607 Precision: 0.8387 Recall: 0.8667
# Epoch 174/250, Batch 27/27 - Loss: 0.0305  Accuracy: 0.7838 F1-Micro: 0.9222 F1-Macro-Avg 0.9326 Precision: 0.9222 Recall: 0.9222
# Epoch 175/250, Batch 27/27 - Loss: 0.0290  Accuracy: 0.5676 F1-Micro: 0.8750 F1-Macro-Avg 0.8655 Precision: 0.8953 Recall: 0.8556
# Epoch 176/250, Batch 27/27 - Loss: 0.0367  Accuracy: 0.6757 F1-Micro: 0.8927 F1-Macro-Avg 0.8870 Precision: 0.9080 Recall: 0.8778
# Epoch 177/250, Batch 27/27 - Loss: 0.0197  Accuracy: 0.6216 F1-Micro: 0.8814 F1-Macro-Avg 0.8842 Precision: 0.8966 Recall: 0.8667
# Epoch 178/250, Batch 27/27 - Loss: 0.0127  Accuracy: 0.6757 F1-Micro: 0.8837 F1-Macro-Avg 0.8865 Precision: 0.9268 Recall: 0.8444
# Epoch 179/250, Batch 27/27 - Loss: 0.0052  Accuracy: 0.6216 F1-Micro: 0.8800 F1-Macro-Avg 0.8847 Precision: 0.9059 Recall: 0.8556
# Epoch 180/250, Batch 27/27 - Loss: 0.0039  Accuracy: 0.6216 F1-Micro: 0.8864 F1-Macro-Avg 0.8854 Precision: 0.9070 Recall: 0.8667
# Epoch 181/250, Batch 27/27 - Loss: 0.0042  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8984 Precision: 0.9186 Recall: 0.8778
# Epoch 182/250, Batch 27/27 - Loss: 0.0031  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9054 Precision: 0.9294 Recall: 0.8778
# Epoch 183/250, Batch 27/27 - Loss: 0.0029  Accuracy: 0.6757 F1-Micro: 0.8851 F1-Macro-Avg 0.8842 Precision: 0.9167 Recall: 0.8556
# Epoch 184/250, Batch 27/27 - Loss: 0.0034  Accuracy: 0.7027 F1-Micro: 0.9186 F1-Macro-Avg 0.9169 Precision: 0.9634 Recall: 0.8778
# Epoch 185/250, Batch 27/27 - Loss: 0.0029  Accuracy: 0.6757 F1-Micro: 0.8864 F1-Macro-Avg 0.8867 Precision: 0.9070 Recall: 0.8667
# Epoch 186/250, Batch 27/27 - Loss: 0.0030  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8979 Precision: 0.9186 Recall: 0.8778
# Epoch 187/250, Batch 27/27 - Loss: 0.0021  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9148 Precision: 0.9412 Recall: 0.8889
# Epoch 188/250, Batch 27/27 - Loss: 0.0021  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9040 Precision: 0.9294 Recall: 0.8778
# Epoch 189/250, Batch 27/27 - Loss: 0.0023  Accuracy: 0.7027 F1-Micro: 0.9091 F1-Macro-Avg 0.9108 Precision: 0.9302 Recall: 0.8889
# Epoch 190/250, Batch 27/27 - Loss: 0.0022  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9190 Precision: 0.9412 Recall: 0.8889
# Epoch 191/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.9022 Precision: 0.9186 Recall: 0.8778
# Epoch 192/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9190 Precision: 0.9412 Recall: 0.8889
# Epoch 193/250, Batch 27/27 - Loss: 0.0019  Accuracy: 0.6757 F1-Micro: 0.9017 F1-Macro-Avg 0.9069 Precision: 0.9398 Recall: 0.8667
# Epoch 194/250, Batch 27/27 - Loss: 0.0019  Accuracy: 0.6757 F1-Micro: 0.9091 F1-Macro-Avg 0.9130 Precision: 0.9302 Recall: 0.8889
# Epoch 195/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9050 Precision: 0.9294 Recall: 0.8778
# Epoch 196/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.7027 F1-Micro: 0.9080 F1-Macro-Avg 0.9108 Precision: 0.9405 Recall: 0.8778
# Epoch 197/250, Batch 27/27 - Loss: 0.0014  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9040 Precision: 0.9294 Recall: 0.8778
# Epoch 198/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.7027 F1-Micro: 0.8977 F1-Macro-Avg 0.8997 Precision: 0.9186 Recall: 0.8778
# Epoch 199/250, Batch 27/27 - Loss: 0.0019  Accuracy: 0.7027 F1-Micro: 0.9050 F1-Macro-Avg 0.9080 Precision: 0.9101 Recall: 0.9000
# Epoch 200/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7027 F1-Micro: 0.8977 F1-Macro-Avg 0.8986 Precision: 0.9186 Recall: 0.8778
# Epoch 201/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9055 Precision: 0.9294 Recall: 0.8778
# Epoch 202/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9048 Precision: 0.9294 Recall: 0.8778
# Epoch 203/250, Batch 27/27 - Loss: 0.0016  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9055 Precision: 0.9294 Recall: 0.8778
# Epoch 204/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9055 Precision: 0.9294 Recall: 0.8778
# Epoch 205/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7568 F1-Micro: 0.9143 F1-Macro-Avg 0.9206 Precision: 0.9412 Recall: 0.8889
# Epoch 206/250, Batch 27/27 - Loss: 0.0014  Accuracy: 0.7297 F1-Micro: 0.9091 F1-Macro-Avg 0.9146 Precision: 0.9302 Recall: 0.8889
# Epoch 207/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9063 Precision: 0.9294 Recall: 0.8778
# Epoch 208/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7297 F1-Micro: 0.9143 F1-Macro-Avg 0.9188 Precision: 0.9412 Recall: 0.8889
# Epoch 209/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7027 F1-Micro: 0.9080 F1-Macro-Avg 0.9108 Precision: 0.9405 Recall: 0.8778
# Epoch 210/250, Batch 27/27 - Loss: 0.0014  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9066 Precision: 0.9294 Recall: 0.8778
# Epoch 211/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7297 F1-Micro: 0.9040 F1-Macro-Avg 0.9046 Precision: 0.9195 Recall: 0.8889
# Epoch 212/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7027 F1-Micro: 0.8977 F1-Macro-Avg 0.9003 Precision: 0.9186 Recall: 0.8778
# Epoch 213/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7027 F1-Micro: 0.8977 F1-Macro-Avg 0.8997 Precision: 0.9186 Recall: 0.8778
# Epoch 214/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.6757 F1-Micro: 0.8927 F1-Macro-Avg 0.8939 Precision: 0.9080 Recall: 0.8778
# Epoch 215/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8981 Precision: 0.9186 Recall: 0.8778
# Epoch 216/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8981 Precision: 0.9186 Recall: 0.8778
# Epoch 217/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.6757 F1-Micro: 0.8927 F1-Macro-Avg 0.8939 Precision: 0.9080 Recall: 0.8778
# Epoch 218/250, Batch 27/27 - Loss: 0.0017  Accuracy: 0.7027 F1-Micro: 0.9080 F1-Macro-Avg 0.9095 Precision: 0.9405 Recall: 0.8778
# Epoch 219/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9153 Precision: 0.9518 Recall: 0.8778
# Epoch 220/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9055 Precision: 0.9294 Recall: 0.8778
# Epoch 221/250, Batch 27/27 - Loss: 0.0020  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9167 Precision: 0.9518 Recall: 0.8778
# Epoch 222/250, Batch 27/27 - Loss: 0.0016  Accuracy: 0.6757 F1-Micro: 0.9070 F1-Macro-Avg 0.9112 Precision: 0.9512 Recall: 0.8667
# Epoch 223/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7027 F1-Micro: 0.9017 F1-Macro-Avg 0.9015 Precision: 0.9398 Recall: 0.8667
# Epoch 224/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9167 Precision: 0.9518 Recall: 0.8778
# Epoch 225/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7027 F1-Micro: 0.9017 F1-Macro-Avg 0.9015 Precision: 0.9398 Recall: 0.8667
# Epoch 226/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7027 F1-Micro: 0.9017 F1-Macro-Avg 0.9015 Precision: 0.9398 Recall: 0.8667
# Epoch 227/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9098 Precision: 0.9405 Recall: 0.8778
# Epoch 228/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9133 F1-Macro-Avg 0.9167 Precision: 0.9518 Recall: 0.8778
# Epoch 229/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9029 F1-Macro-Avg 0.9055 Precision: 0.9294 Recall: 0.8778
# Epoch 230/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7297 F1-Micro: 0.9040 F1-Macro-Avg 0.9109 Precision: 0.9195 Recall: 0.8889
# Epoch 231/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9066 Precision: 0.9294 Recall: 0.8778
# Epoch 232/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7027 F1-Micro: 0.9143 F1-Macro-Avg 0.9135 Precision: 0.9412 Recall: 0.8889
# Epoch 233/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9098 Precision: 0.9405 Recall: 0.8778
# Epoch 234/250, Batch 27/27 - Loss: 0.0012  Accuracy: 0.7297 F1-Micro: 0.9080 F1-Macro-Avg 0.9098 Precision: 0.9405 Recall: 0.8778
# Epoch 235/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7027 F1-Micro: 0.8966 F1-Macro-Avg 0.8979 Precision: 0.9286 Recall: 0.8667
# Epoch 236/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9040 Precision: 0.9294 Recall: 0.8778
# Epoch 237/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7027 F1-Micro: 0.8977 F1-Macro-Avg 0.8997 Precision: 0.9186 Recall: 0.8778
# Epoch 238/250, Batch 27/27 - Loss: 0.0013  Accuracy: 0.7838 F1-Micro: 0.9205 F1-Macro-Avg 0.9152 Precision: 0.9419 Recall: 0.9000
# Epoch 239/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7297 F1-Micro: 0.9195 F1-Macro-Avg 0.9177 Precision: 0.9524 Recall: 0.8889
# Epoch 240/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9021 Precision: 0.9294 Recall: 0.8778
# Epoch 241/250, Batch 27/27 - Loss: 0.0015  Accuracy: 0.7027 F1-Micro: 0.9091 F1-Macro-Avg 0.9091 Precision: 0.9302 Recall: 0.8889
# Epoch 242/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9101 F1-Macro-Avg 0.9076 Precision: 0.9205 Recall: 0.9000
# Epoch 243/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9010 Precision: 0.9294 Recall: 0.8778
# Epoch 244/250, Batch 27/27 - Loss: 0.0010  Accuracy: 0.7027 F1-Micro: 0.9029 F1-Macro-Avg 0.9026 Precision: 0.9294 Recall: 0.8778
# Epoch 245/250, Batch 27/27 - Loss: 0.0008  Accuracy: 0.7027 F1-Micro: 0.8989 F1-Macro-Avg 0.8985 Precision: 0.9091 Recall: 0.8889
# Epoch 246/250, Batch 27/27 - Loss: 0.0009  Accuracy: 0.7027 F1-Micro: 0.8989 F1-Macro-Avg 0.8985 Precision: 0.9091 Recall: 0.8889
# Epoch 247/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7568 F1-Micro: 0.9101 F1-Macro-Avg 0.9092 Precision: 0.9205 Recall: 0.9000
# Epoch 248/250, Batch 27/27 - Loss: 0.0011  Accuracy: 0.7297 F1-Micro: 0.9040 F1-Macro-Avg 0.9046 Precision: 0.9195 Recall: 0.8889
# Epoch 249/250, Batch 27/27 - Loss: 0.0008  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8971 Precision: 0.9186 Recall: 0.8778
# Epoch 250/250, Batch 27/27 - Loss: 0.0007  Accuracy: 0.6757 F1-Micro: 0.8927 F1-Macro-Avg 0.8942 Precision: 0.9080 Recall: 0.8778

# %%
plot_losses(trainLosses, evalLosses)

# %%
globalMetricsDf, labelMetricsDf = eval_metrics_to_df(evalMetrics)

# %%
globalMetricsDf
# Out:
#        loss  accuracy  precision    recall  f1_micro  f1_macro_avg  \
# 0  0.126959  0.675676   0.908046  0.877778  0.892655       0.89422
#
#    f1_weighted_avg
# 0         0.891379

# %%
labelMetricsDf
# Out:
#                                       precision    recall  f1-score  support
# aide_hygiene_personnelle               0.714286  1.000000  0.833333      5.0
# commission_faire_marche                0.923077  1.000000  0.960000     12.0
# cuisiner                               0.833333  0.714286  0.769231      7.0
# logistique_medicale                    0.857143  0.857143  0.857143      7.0
# menage_epoussetage                     1.000000  0.833333  0.909091      6.0
# menage_lessive                         1.000000  0.800000  0.888889     10.0
# menage_plancher                        1.000000  1.000000  1.000000      7.0
# mobilite_confort                       1.000000  1.000000  1.000000      9.0
# mobilite_transport_accompagnement_rv   0.727273  0.666667  0.695652     12.0
# nourrir_personne                       1.000000  1.000000  1.000000      8.0
# stimulation_dame_compagnie             1.000000  0.857143  0.923077      7.0
