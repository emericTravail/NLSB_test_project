# %%
# !nvidia-smi
# Out:
# Tue Mar 10 13:45:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   34C    P0             52W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
import gc
import sys
import torch
import json
import numpy as np
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report
from torch.utils.data import TensorDataset, DataLoader, random_split, Dataset
from torch import nn
from transformers import AutoTokenizer, AutoModel, AutoModelForMaskedLM, BertTokenizerFast, BertTokenizer, BertForSequenceClassification, DataCollatorForLanguageModeling, TrainingArguments, Trainer, AutoConfig
import matplotlib.pyplot as plt
import torch.nn.functional as F
import random
import torch
import datasets
import time

# %%
print('Working dir:', os.getcwd())
# Out:
# Working dir: /content

# %%
# All models
BERT = "bert-base-multilingual-cased"
ROBERTA = "FacebookAI/xlm-roberta-base" # Roberta multilangual
CAMEMBERT = "camembert-base" # RoBerta adapted for french
DISTIL_CAMEMBERT = "cmarkea/distilcamembert-base" # CAMEMBERT french smaller
LONGFORMER = "abazoge/DrLongformer"
BIGBIRD = "google/bigbird-roberta-base"

# %% [markdown]
# Data Preprocessing

# %%
"""
Module to transform data to be consumable by model
"""

class DatabaseToBertDataset():
    def __init__(self, model_name):
        if model_name == DISTIL_CAMEMBERT:
            model_name = CAMEMBERT
        self.tokenizer = AutoTokenizer.from_pretrained(model_name) # ("bert-base-multilingual-cased")
        self.tokenizerChunkLen = self.tokenizer.model_max_length

        config = AutoConfig.from_pretrained(model_name)
        self.maxTokensLength = config.max_position_embeddings


        # "allenai/longformer-base-4096" has no max_length
        if model_name == CAMEMBERT or DISTIL_CAMEMBERT:
            self.maxTokensLength = 512
        if model_name == LONGFORMER:
            self.maxTokensLength = 4096

    def _tokenize(self, df: str) -> pd.DataFrame:
        """Tokenizer function"""
        tokenized = self.tokenizer(
            df["email"].to_list(),
            df["bill"].to_list(),
            padding='max_length',
            max_length=self.maxTokensLength,
            truncation=True,
            stride=128,                        # overlap between chunks
            return_overflowing_tokens=True,    # keep extra chunks
            return_offsets_mapping=True,       # optional: track positions in original text
            return_tensors="pt"                # PyTorch tensors
        )

        # input(tokenized.keys())

        # print(type(tokenized))
        # print(tokenized['input_ids'].shape)
        # print(tokenized['token_type_ids'].shape)
        # print(tokenized['attention_mask'].shape)
        # print(tokenized['offset_mapping'].shape)
        # print(tokenized['overflow_to_sample_mapping'].shape)
        # input('MMMM')

        return tokenized

    def tokenize_by_row(self, row: pd.Series):
        text = self._join_text_fields(row)
        tokenized = self.tokenizer(
            text,
            padding='max_length',
            max_length=self.maxTokensLength,
            truncation=True,
            stride=128,                        # overlap between chunks
            return_overflowing_tokens=True,    # keep extra chunks
            return_offsets_mapping=True,       # optional: track positions in original text
            return_tensors="pt"                # PyTorch tensors
        )

        return tokenized

    def _join_text_fields(self, row):
        parts = []
        for k in ["email", "bill"]:
            if row[k]:
                parts.append(row[k])
        return " [SEP] ".join(parts)

    def _encode_labels(self, df: pd.DataFrame) -> tuple[pd.DataFrame, np.ndarray]:
        """Encode labels"""

        df = df.copy()
        # Get unique labels from labels description
        with open('labels.json', 'r') as file:
            labels = json.load(file)['etiquettes']
        labelIds = [label['id'] for label in labels]

        # Format original labels
        df['labels'] = df['labels'].apply(
            lambda x: x.split('|') if isinstance(x, str) else []
        )

        # Encode
        mlb = MultiLabelBinarizer(classes=labelIds)
        encoded = mlb.fit_transform(df['labels'])
        df = pd.concat(
            [df, pd.DataFrame(encoded, columns=mlb.classes_)],
            axis=1
        )
        df = df.drop(columns='labels')

        return df, mlb.classes_


    def execute(self, df : pd.DataFrame) -> tuple[dict[torch.Tensor], np.ndarray]:
        """
        Transform from database to dataset consumable by model
        """
        df = df.copy()
        # Tokenize ('input_ids' 'attention_mask''token_type_ids' 'overflow_to_sample_mapping')
        tokenized = df.apply(lambda row: self.tokenize_by_row(row), axis=1)


        labels = None
        if 'labels' in df.columns:
            df, labelNames = self._encode_labels(df)
            labels = torch.tensor(df[labelNames].to_numpy())

        return tokenized.to_list(),  labels, labelNames

# %%
# def collate_variable_docs(batch, pad_token_id=0):
#     """
#     batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
#     where each input_ids has shape [num_chunks, 512]
#     """
#
#     input_ids_list, attn_list, token_type_list, label_list = zip(*batch)
#
#     # Find max num_chunks in this batch
#     max_chunks = max(x.shape[0] for x in input_ids_list)
#     chunk_len = input_ids_list[0].shape[1]
#
#     def pad_to_max_chunks(x, pad_val = 0):
#         pad_chunks = max_chunks - x.shape[0]
#         if pad_chunks > 0:
#             pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
#             x = torch.cat([x, pad], dim=0)
#         return x
#
#     input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
#     attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
#     token_types = torch.stack([pad_to_max_chunks(x) for x in token_type_list])
#     labels = torch.stack(label_list)
#
#     return input_ids, attn_mask, token_types, labels
#
# class BertTokenizedDataset(Dataset):
#     def __init__(self, data, labels):
#         self.data = data
#         self.labels = labels
#
#     def __len__(self):
#         return len(self.data)
#
#     def __getitem__(self, idx):
#         # Just return what you already have
#         sample = self.data[idx]
#         x = []
#         return sample['input_ids'], sample['attention_mask'], sample['token_type_ids'], self.labels[idx]
#
# databaseToBertDataset = DatabaseToBertDataset(model_name="bert-base-multilingual-cased")
# df = pd.read_csv('data.csv')
# data, labels, labels_list = databaseToBertDataset.execute(df)
#
#
# dataset = BertTokenizedDataset(
#     data,
#     labels,
# )
#
#
# train_loader = DataLoader(dataset, batch_size=4, shuffle=True,
#                           collate_fn=(lambda batch: collate_variable_docs(batch, databaseToBertDataset.tokenizer.pad_token_id)))
#
#
# for batch_idx, batch in enumerate(train_loader):
#
#     input_ids = batch[0]
#     attention_mask = batch[1]
#     token_type_ids = batch[2]
#     labels = batch[3]
#
#     print('asdasdasd')
#     print(input_ids[0])
#     print(attention_mask.shape)
#     print(token_type_ids.shape)
#     print(labels.shape)
#

# %% [markdown]
# Models

# %%
class BertHierachicalClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)


        self.chunk_transformer = nn.TransformerEncoderLayer(
            d_model=self.bert.config.hidden_size,
            nhead=8,
            batch_first=True
        )

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]
        token_type_ids = batch[2]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)
        if token_type_ids is not None:
            token_type_ids = token_type_ids.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document


        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierachicalClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(0.2)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierachicalLsanClassifier(nn.Module):
    def __init__(self, model_name, num_labels, model_dapt=None, d_a=200, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        if model_dapt is None:
          self.bert = AutoModel.from_pretrained(self.modelName)
        else:
          self.bert = model_dapt
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(0.2)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=8, batch_first=True)

        # === LSAN Part ===
        # Self-attention per label
        self.W1 = nn.Linear(H, d_a)          # (H → d_a)
        self.W2 = nn.Linear(d_a, num_labels) # (d_a → L)

        # Label attention
        self.C = nn.Parameter(torch.randn(num_labels, H))

        # Adaptive Attention
        self.W3 = nn.Parameter(torch.randn(H))
        self.W4 = nn.Parameter(torch.randn(H))

        # Classifier
        # self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels) OLD

        self.W_cls = nn.Parameter(torch.randn(num_labels, H))  # (L, H)
        self.b_cls = nn.Parameter(torch.zeros(num_labels))

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings) # (batch_size, nbr_encoding, encoding_dim)
        # doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # === LSAN Part ===
        # Self-attention per label
        Q_s = torch.tanh(self.W1(doc_embeds)) # [batch_size, nbr_encoding, d_a]
        K_s = self.W2(Q_s) # [batch_size, nbr_encoding, nbr_labels]
        A_s = torch.softmax(K_s.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_s = torch.matmul(A_s, doc_embeds) # [batch_size, nbr_labels, encoding_dim]

        # Label-attention
        A_l = torch.matmul(doc_embeds, self.C.T) # [batch_size, nbr_encoding, nbr_labels]
        A_l = torch.softmax(A_l.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_l = torch.matmul(A_l, doc_embeds) # [batch_size, nbr_labels, nbr_encoding]

        # Adaptive Attention Fusion
        a = torch.sigmoid(torch.matmul(M_s, self.W3)) # [batch_size, nbr_labels]
        b = torch.sigmoid(torch.matmul(M_l, self.W4)) # [batch_size, nbr_labels]
        s = a + b + 1e-8 # a_i + b_i = 1
        a = a / s
        b = b / s
        M_j = a.unsqueeze(-1) * M_s + b.unsqueeze(-1) * M_l # [batch_size, nbr_labels, nbr_encoding]



        # Classification
        out = (M_j * self.W_cls.unsqueeze(0)).sum(-1) + self.b_cls

        return out

class CamembertHierachicalLsanClassifierDep(nn.Module):
    def __init__(self, model_name, num_labels, model_dapt=None, nhead=8, d_a=200, drop_out = 0.2, freeze_bert=False):
        super().__init__()
        print(f'Init model CamembertHierachicalLsanClassifierDep(model_dapt={type(model_dapt)}, model_name={model_name}, num_labels={num_labels}, d_a={d_a}, drop_out={drop_out} freeze_bert={freeze_bert})')
        self.modelName = model_name
        if model_dapt is None:
          self.bert = AutoModel.from_pretrained(self.modelName)
        else:
          self.bert = model_dapt
        H = self.bert.config.hidden_size

        self.dropout = nn.Dropout(drop_out)

        self.max_chunks = 32
        self.chunk_pos_emb = nn.Embedding(self.max_chunks, H)

        self.chunk_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=nhead, batch_first=True)

        # === LSAN Part ===
        # Self-attention per label
        self.W1 = nn.Linear(H, d_a)          # (H → d_a)
        self.W2 = nn.Linear(d_a, num_labels) # (d_a → L)

        # Label attention
        self.C = nn.Parameter(torch.randn(num_labels, H))

        # Adaptive Attention
        self.W3 = nn.Parameter(torch.randn(H))
        self.W4 = nn.Parameter(torch.randn(H))

        # Classifier
        self.label_transformer = nn.TransformerEncoderLayer(d_model=H, nhead=nhead, batch_first=True)
        # self.classifier = nn.Linear(H, num_labels)
        hidden = H // 2
        self.classifier = nn.Sequential(
            nn.LayerNorm(H),
            nn.Linear(H, hidden),
            nn.GELU(),
            nn.Dropout(drop_out),
            nn.Linear(hidden, num_labels)
        )

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = x[0]
        attention_mask = x[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # outputs.pooler_output: [B*N, hidden]
        chunk_embeddings = outputs.pooler_output
        chunk_embeddings = chunk_embeddings.view(B, N, -1)  # group back by document

        # --- positional embeddings (NO concat, NO dim change) ---
        pos_ids = torch.arange(N, device=chunk_embeddings.device).unsqueeze(0).expand(B, N)  # [B,N]
        pos_ids = pos_ids.clamp(max=self.max_chunks - 1)
        chunk_embeddings = chunk_embeddings + self.chunk_pos_emb(pos_ids)  # [B,N,H]


        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings) # (batch_size, nbr_encoding, encoding_dim)
        # doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks (batch_size, encoding_dim)

        # === LSAN Part ===
        # Self-attention per label
        Q_s = torch.tanh(self.W1(doc_embeds)) # [batch_size, nbr_encoding, d_a]
        K_s = self.W2(Q_s) # [batch_size, nbr_encoding, nbr_labels]
        A_s = torch.softmax(K_s.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_s = torch.matmul(A_s, doc_embeds) # [batch_size, nbr_labels, encoding_dim]

        # Label-attention
        A_l = torch.matmul(doc_embeds, self.C.T) # [batch_size, nbr_encoding, nbr_labels]
        A_l = torch.softmax(A_l.transpose(1, 2), dim=-1) # [batch_size, nbr_labels, nbr_encoding]
        M_l = torch.matmul(A_l, doc_embeds) # [batch_size, nbr_labels, nbr_encoding]

        # Adaptive Attention Fusion
        a = torch.sigmoid(torch.matmul(M_s, self.W3)) # [batch_size, nbr_labels]
        b = torch.sigmoid(torch.matmul(M_l, self.W4)) # [batch_size, nbr_labels]
        s = a + b + 1e-8 # a_i + b_i = 1
        a = a / s
        b = b / s
        M_j = a.unsqueeze(-1) * M_s + b.unsqueeze(-1) * M_l # [batch_size, nbr_labels, nbr_encoding]

        # Classification
        M_j_aggragated = self.label_transformer(M_j) # [batch_size, nbr_labels, nbr_encoding]
        M_j_aggragated = M_j_aggragated.mean(dim=1) # [batch_size, nbr_encoding]
        out = self.classifier(self.dropout(M_j_aggragated))

        return out

class CamembertHierachicalClassifierV2(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)


        self.chunk_transformer = nn.TransformerEncoderLayer(
            d_model=self.bert.config.hidden_size,
            nhead=8,
            batch_first=True
        )

        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids = batch[0]
        attention_mask = batch[1]

        B, N, L = input_ids.shape

        # Merge batch and chunk dims: treat all chunks as separate sequences
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # Pass through BERT (TAKE ALL OUTPUT)
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        token_emb = outputs.last_hidden_state              # [B*N, L, H]
        mask = attention_mask.unsqueeze(-1).float()        # [B*N, L, 1]

        # masked mean pooling
        sum_emb = (token_emb * mask).sum(dim=1)            # [B*N, H]
        len_emb = mask.sum(dim=1).clamp(min=1e-6)          # [B*N, 1]
        chunk_embeddings = sum_emb / len_emb               # [B*N, H]

        chunk_embeddings = chunk_embeddings.view(B, N, -1) # [B, N, H]

        # Aggregate chunk embeddings (you can replace with attention or mean)
        doc_embeds = self.chunk_transformer(chunk_embeddings)
        doc_embeds = doc_embeds.mean(dim=1)  # mean over chunks

        # Classification
        out = self.classifier(self.dropout(doc_embeds))

        return out

class CamembertHierarchicalGRUClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False, gru_hidden=384, num_gru_layers=1):
        super().__init__()

        self.modelName = model_name
        self.bert = AutoModel.from_pretrained(self.modelName)

        hidden_size = self.bert.config.hidden_size

        # ---- GLOBAL ENCODER: BiGRU over chunks ----
        self.gru = nn.GRU(
            input_size=hidden_size,
            hidden_size=gru_hidden,
            num_layers=num_gru_layers,
            batch_first=True,
            bidirectional=True
        )

        self.dropout = nn.Dropout(0.2)

        # Final classifier: takes BiGRU output (2*hidden because bidirectional)
        self.classifier = nn.Linear(gru_hidden * 2, num_labels)

        # Optionally freeze BERT
        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False


    def forward(self, batch):
        input_ids = batch[0]          # (B, N, L)
        attention_mask = batch[1]     # (B, N, L)

        B, N, L = input_ids.shape

        # ---- Flatten chunks so BERT can process them in one batch ----
        input_ids = input_ids.view(B * N, L)
        attention_mask = attention_mask.view(B * N, L)

        # ---- Local transformer over tokens ----
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
        )

        # One embedding per chunk → [CLS] or pooler_output
        chunk_emb = outputs.last_hidden_state[:, 0, :]     # (B*N, hidden)
        # If CamemBERT returns None for pooler_output, use CLS token:
        # chunk_embeddings = outputs.last_hidden_state[:, 0, :]

        # Rebuild (B, N, hidden)
        chunk_emb = chunk_emb.view(B, N, -1)

        # GRU
        # h_n: (num_layers * num_directions, B, hidden)
        _, h_n = self.gru(chunk_emb)

        # Extract final BiGRU state
        # h_n[-2] = final state of backward
        # h_n[-1] = final state of forward
        h_forward = h_n[-1]
        h_backward = h_n[-2]
        doc_rep = torch.cat([h_backward, h_forward], dim=-1)

        logits = self.classifier(self.dropout(doc_rep))

        return logits


class LongformerClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        # "allenai/longformer-base-4096" NOT IN FRENCH... :(
        self.modelName = LONGFORMER
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids, attention_mask = x

        # BERT outputs all hidden states
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Apply dropout + classification on the pooled [CLS] representation
        out = self.classifier(self.dropout(pooled_output))

        return out

class BigbirdClassifier(nn.Module):
    def __init__(self, model_name, num_labels, freeze_bert=False):
        super().__init__()
        self.modelName = BIGBIRD
        self.bert = AutoModel.from_pretrained(self.modelName)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

        if freeze_bert:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, x):
        input_ids, attention_mask = x

        # BERT outputs all hidden states
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # The BERT model returns:
        # - last_hidden_state: (batch_size, seq_len, hidden_dim)
        # - pooler_output: (batch_size, hidden_dim)
        last_hidden_state = outputs.last_hidden_state # (batch_size, seq_len, hidden_dim)
        pooled_output = outputs.pooler_output  # [CLS] embedding after tanh layer

        # Apply dropout + classification on the pooled [CLS] representation
        out = self.classifier(self.dropout(pooled_output))

        return out

# %% [markdown]
# Evaluate

# %%
def compute_eval_metrics(loss, all_labels, all_preds, labels_list) -> dict[list[float]]:
  """
  Computes evaluation metrics
  """
  f1Report = classification_report(all_labels, all_preds, target_names=labels_list, output_dict=True, zero_division=0)


  eval_metric = {}
  eval_metric['loss'] = loss
  eval_metric['accuracy'] = accuracy_score(all_labels, all_preds)
  eval_metric['precision'] = f1Report["micro avg"]["precision"]
  eval_metric['recall'] = f1Report["micro avg"]["recall"]
  eval_metric['f1_micro'] = f1Report["micro avg"]["f1-score"]
  eval_metric['f1_macro_avg'] = f1Report["macro avg"]["f1-score"]
  eval_metric['f1_weighted_avg'] = f1Report["weighted avg"]["f1-score"]
  eval_metric['f1_macro'] = f1Report

  return eval_metric


def print_global_eval_metrics(eval_metrics, exec_time=None):
    """
    Print mean metrics
    """

    loss = eval_metrics['loss']
    accuracy = eval_metrics['accuracy']
    precision = eval_metrics['precision']
    recall = eval_metrics['recall']
    f1Micro = eval_metrics['f1_micro']
    f1MacroAvg = eval_metrics['f1_macro_avg']

    to_print = f"  Accuracy: {accuracy:.4f} F1-Micro: {f1Micro:.4f} F1-Macro-Avg {f1MacroAvg:.4f} Precision: {precision:.4f} Recall: {recall:.4f}"
    if exec_time is not None:
      to_print += f" ({exec_time:.6f}s)"

    print(to_print)


def eval_metrics_to_df(eval_metrics) -> tuple[pd.DataFrame]:
    """
    Full display all metrics
    """

    # Golbal metrics
    globalMetrics = {}
    for metricName, val in eval_metrics.items():
        if 'f1_macro' == metricName:
          continue
        globalMetrics[metricName] = val
    globalMetricsDf = pd.DataFrame([globalMetrics])


    # Label metrics
    f1MacrosDf = pd.DataFrame(eval_metrics['f1_macro']).transpose()
    # f1MacrosDf = pd.concat(f1MacrosDfs).groupby(level=0).mean(numeric_only=True)
    f1MacrosDf = f1MacrosDf.drop(index=["micro avg", "macro avg", "weighted avg", "samples avg"])

    return globalMetricsDf, f1MacrosDf


def calc_eval_metric_epochs_mean(eval_metric_epochs):
    epoch_global_eval_mean = {}

    keys = list(eval_metric_epochs[0].keys())
    for k in keys:
      if k == 'f1_macro':
        continue
      epoch_global_eval_mean[k] = 0
      for eval_metric_epoch in eval_metric_epochs:
        epoch_global_eval_mean[k] = epoch_global_eval_mean[k] + eval_metric_epoch[k]
      epoch_global_eval_mean[k] = epoch_global_eval_mean[k] / len(eval_metric_epochs)


    f1_macro_mean = {}
    f1_macro_sample = eval_metric_epochs[0]['f1_macro']
    keys1 = list(f1_macro_sample.keys())
    keys2 = list(f1_macro_sample[keys1[0]].keys())
    for key1 in keys1:
        f1_macro_mean[key1] = {}
        for key2 in keys2:
            n = 0
            f1_macro_mean[key1][key2] = 0
            for eval_metric_epoch in eval_metric_epochs:
                if key1 in eval_metric_epoch['f1_macro'].keys():
                  n += 1
                  f1_macro_mean[key1][key2] += eval_metric_epoch['f1_macro'][key1][key2]
            f1_macro_mean[key1][key2] = f1_macro_mean[key1][key2] / n
    epoch_global_eval_mean['f1_macro'] = f1_macro_mean

    return epoch_global_eval_mean

def plot_losses(trainLosses, evalLosses):
    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(trainLosses, label='Training Loss', marker='o')
    plt.plot(evalLosses, label='Validation Loss', marker='o')

    plt.yscale('log')

    plt.title('Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# Train

# %%
def collate_variable(batch, pad_token_id=0):
    """
    batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
    where each input_ids has shape [num_chunks, 512]
    """

    input_ids_list, attn_list, token_type_list, label_list = zip(*batch)

    # Find max num_chunks in this batch
    max_chunks = max(x.shape[0] for x in input_ids_list)
    chunk_len = input_ids_list[0].shape[1]

    def pad_to_max_chunks(x, pad_val = 0):
        pad_chunks = max_chunks - x.shape[0]
        if pad_chunks > 0:
            pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
            x = torch.cat([x, pad], dim=0)
        return x

    input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
    attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
    token_types = torch.stack([pad_to_max_chunks(x) for x in token_type_list])
    labels = torch.stack(label_list).float()

    return input_ids, attn_mask, token_types, labels

def collate_variable_no_token_types(batch, pad_token_id=0):
    """
    batch: list of tuples (input_ids, attn_mask, token_type_ids, label)
    where each input_ids has shape [num_chunks, 512]
    """

    input_ids_list, attn_list, label_list = zip(*batch)

    # Find max num_chunks in this batch
    max_chunks = max(x.shape[0] for x in input_ids_list)
    chunk_len = input_ids_list[0].shape[1]

    def pad_to_max_chunks(x, pad_val = 0):
        pad_chunks = max_chunks - x.shape[0]
        if pad_chunks > 0:
            pad = torch.full((pad_chunks, chunk_len), pad_val, dtype=torch.long)
            x = torch.cat([x, pad], dim=0)
        return x

    input_ids = torch.stack([pad_to_max_chunks(x, pad_token_id) for x in input_ids_list])
    attn_mask = torch.stack([pad_to_max_chunks(x) for x in attn_list])
    labels = torch.stack(label_list).float()

    return input_ids, attn_mask, labels

class TokenizedDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        self.collateFunc = collate_variable

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Just return what you already have
        sample = self.data[idx]
        x = []
        return sample['input_ids'], sample['attention_mask'], sample['token_type_ids'], self.labels[idx]


class TokenizedDatasetNoType(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        self.collateFunc = collate_variable_no_token_types

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Just return what you already have
        sample = self.data[idx]
        x = []
        return sample['input_ids'], sample['attention_mask'], self.labels[idx]

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

    # For multi-GPU
    torch.cuda.manual_seed_all(seed)

    # Make cuDNN deterministic (slower but reproducible)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def disable_seed():
    random.seed(None)
    np.random.seed(None)
    torch.seed()  # random new seed
    torch.cuda.seed()
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

# %%
def pretrain_model(model_name, trainDf, train_data, databaseToBertDataset, hyperparams={}):

    tokenizer = databaseToBertDataset.tokenizer

    # Hyperparams
    lr = hyperparams.get('lr_dapt', 2e-5)
    warmup_ratio = hyperparams.get('warmup_ratio_dapt', 0.06)
    max_steps = hyperparams.get('max_steps_dapt', 40000)
    stride = hyperparams.get('stride_dapt', 128)



    # 1) Build texts (add a separator like newline so fields don’t merge words)
    texts = (
        trainDf["email"].fillna("").astype(str)
        + "\n"
        + trainDf["bill"].fillna("").astype(str)
    ).tolist()

    ds = datasets.Dataset.from_dict({"text": texts})

    # 2) Tokenize (overflow creates multiple chunks per text)
    def tok(batch):
        return tokenizer(
            batch["text"],
            truncation=True,
            max_length=databaseToBertDataset.maxTokensLength,
            return_overflowing_tokens=True,
            stride=stride,
            padding=False,  # IMPORTANT: pad later in collator
        )

    ds_tok = ds.map(tok, batched=True, remove_columns=["text"])

    # 3) Model + MLM collator
    model = AutoModelForMaskedLM.from_pretrained(model_name)
    collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer,
        mlm=True,
        mlm_probability=0.15
    )

    args = TrainingArguments(
        output_dir=f"{model_name}_dapt",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=2,
        learning_rate=lr,
        weight_decay=0.01,
        warmup_ratio=warmup_ratio,
        max_steps=max_steps,
        # fp16=True,
        logging_steps=50,
        save_steps=1000,
        save_total_limit=2,
        report_to="none",
        bf16=True,           # Reduce precision (a lot faster)
        bf16_full_eval=True, # Reduce precision (a lot faster)
    )
    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=ds_tok,     # ✅ TRAIN ON TOKENIZED DATASET
        data_collator=collator,
    )

    trainer.train()
    trainer.save_model(f"{model_name}_dapt")
    tokenizer.save_pretrained(f"{model_name}_dapt")

    model = AutoModel.from_pretrained(f"{model_name}_dapt")

    return model

# %%
seed = 42
set_seed(seed)

HIERACHICAL_TRANSFORMER = 'HIERACHICAL_TRANSFORMER'
HIERACHICAL_TRANSFORMERV2 = 'HIERACHICAL_TRANSFORMERV2'
HIERACHICAL_TRANSFORMER_LSAN = 'HIERACHICAL_TRANSFORMER_LSAN'
HIERACHICAL_TRANSFORMER_LSAN_DEP = 'HIERACHICAL_TRANSFORMER_LSAN_DEP'
HIERACHICAL_GRU = 'HIERACHICAL_GRU'


gc.collect()
torch.cuda.empty_cache()

# Read data
df = pd.read_csv('data.csv')
df['bills'].fillna('', inplace=True)
df = df.rename(columns={"emails": "email", "bills": "bill"})
df['labels'] = df['labels'].apply(lambda x: x.replace(' ', '').replace(',', '|') if isinstance(x, str) else [])


# Train/val/test split
trainRatio = 0.7
valRatio = 0.25
testRatio = 0.05
trainDf, valTestDf = train_test_split(df, train_size=trainRatio, random_state=42)
relativeRatio = valRatio/(valRatio + testRatio)
valDf, testDf = train_test_split(valTestDf, train_size=relativeRatio, random_state=42)

trainDf = trainDf.reset_index()
valDf = valDf.reset_index()
testDf = testDf.reset_index()

# === CONFIG ===
MODEL_NAME_BERT =  CAMEMBERT # ROBERTA # DISTIL_CAMEMBERT # CAMEMBERT # BERT
MODEL_NAME = HIERACHICAL_TRANSFORMER_LSAN_DEP # HIERACHICAL_TRANSFORMER # HIERACHICAL_TRANSFORMERV2 # HIERACHICAL_TRANSFORMER_LSAN # HIERACHICAL_TRANSFORMER_LSAN_DEP # HIERACHICAL_GRU
def train(epochs, batch_size, hyperparams, no_improvements_stop = None):
  PRETRAIN = False
  epochs = epochs
  batch_size = batch_size

  # Hyperparams
  lr = hyperparams.get('lr', 2e-5)
  drop_out = hyperparams.get('drop_out', 2e-5)
  d_a = hyperparams.get('d_a', 200)
  nhead = hyperparams.get('nhead', 8)
  weight_decay = hyperparams.get('weight_decay', 0.01)


  threshold = 0.5
  window_eval_mean = 7
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  print(f'CONFIG: batch_size={batch_size}, epochs={epochs}, device={device}')
  print('')


  # === Tokenize ===
  databaseToBertDataset = DatabaseToBertDataset(model_name=MODEL_NAME_BERT)
  train_data, train_labels, labels_list = databaseToBertDataset.execute(trainDf)
  val_data, val_labels, _ = databaseToBertDataset.execute(valDf)

  # === Pretrain ===
  model_dapt = None
  if PRETRAIN:
    model_dapt = pretrain_model(MODEL_NAME_BERT, trainDf, train_data, databaseToBertDataset, hyperparams)


  if MODEL_NAME_BERT == BERT:
      # === Datasets ===
      train_dataset = TokenizedDataset(
          train_data,
          train_labels
      )
      val_dataset = TokenizedDataset(
          val_data,
          val_labels
      )

      # === Model ===
      model = BertHierachicalClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

  elif MODEL_NAME_BERT == CAMEMBERT or MODEL_NAME_BERT == DISTIL_CAMEMBERT or MODEL_NAME_BERT == ROBERTA:

      # === Datasets ===
      train_dataset = TokenizedDatasetNoType(
          train_data,
          train_labels
      )
      val_dataset = TokenizedDatasetNoType(
          val_data,
          val_labels
      )

      # === Model ===
      if MODEL_NAME == HIERACHICAL_TRANSFORMER:
          model = CamembertHierachicalClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))
      elif MODEL_NAME == HIERACHICAL_TRANSFORMERV2:
          model = CamembertHierachicalClassifierV2(MODEL_NAME_BERT, num_labels=len(labels_list))
      elif MODEL_NAME == HIERACHICAL_TRANSFORMER_LSAN:
          model = CamembertHierachicalLsanClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))
      elif MODEL_NAME == HIERACHICAL_TRANSFORMER_LSAN_DEP:
          model = CamembertHierachicalLsanClassifierDep(
              MODEL_NAME_BERT, num_labels=len(labels_list), model_dapt=model_dapt,
              drop_out=drop_out, nhead=nhead, d_a=d_a, freeze_bert=False
          )
      elif MODEL_NAME == HIERACHICAL_GRU:
          model = CamembertHierarchicalGRUClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

  elif MODEL_NAME_BERT == LONGFORMER:

      # === Datasets ===
      train_dataset = TensorDataset(
          train_data["input_ids"],
          train_data["attention_mask"],
          train_data["labels"].float()
      )
      val_dataset = TensorDataset(
          val_data["input_ids"],
          val_data["attention_mask"],
          val_data["labels"].float()
      )

      # === Model ===
      model = LongformerClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))

  elif MODEL_NAME_BERT == BIGBIRD:

      # === Datasets ===
      train_dataset = TensorDataset(
          train_data["input_ids"],
          train_data["attention_mask"],
          train_data["labels"].float()
      )
      val_dataset = TensorDataset(
          val_data["input_ids"],
          val_data["attention_mask"],
          val_data["labels"].float()
      )

      # === Model ===
      model = BigbirdClassifier(MODEL_NAME_BERT, num_labels=len(labels_list))


  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
            collate_fn=(lambda batch: train_dataset.collateFunc(batch, databaseToBertDataset.tokenizer.pad_token_id)))

  val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False,
            collate_fn=(lambda batch: val_dataset.collateFunc(batch, databaseToBertDataset.tokenizer.pad_token_id)))

  model = model.to(device)
  optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
  criterion = nn.BCEWithLogitsLoss()

  best_f1 = -9999
  best_global_evals = None
  best_eval_metric = None
  trainLosses = []
  evalLosses = []
  eval_metric_epochs = []

  # === TRAINING LOOP ===
  scaler = torch.amp.GradScaler("cuda")
  for epoch in range(epochs):
      start = time.perf_counter()
      model.train()

      sumLoss = 0.0
      for batch_idx, batch in enumerate(train_loader):
          batch = [t.to(device, non_blocking=True) for t in batch]
          # batch = {k: v.to(device, non_blocking=True) for k, v in batch.items()}

          xTensor = batch[:-1]
          labels = batch[-1]

          optimizer.zero_grad()

          with torch.amp.autocast("cuda", dtype=torch.bfloat16):
            # Forward
            outputs = model(xTensor)
            # Compute loss
            loss = criterion(outputs, labels)
            # print(labels)
            # print(outputs.shape)
            # input(loss.item())

          scaler.scale(loss).backward()
          scaler.step(optimizer)
          scaler.update()
          # loss.backward()
          # optimizer.step()

          sumLoss += loss.item()
          sys.stdout.write(f"\rEpoch {epoch+1}/{epochs}, Batch {batch_idx+1}/{len(train_loader)} - Loss: {loss.item():.4f}")
          sys.stdout.flush()

      meanLoss = sumLoss / len(train_loader)
      trainLosses.append(meanLoss)
      sys.stdout.write(f"\rEpoch {epoch+1}/{epochs}, Batch {len(train_loader)}/{len(train_loader)} - Loss: {meanLoss:.4f}")
      sys.stdout.flush()

      # === EVALUATION LOOP ===
      model.eval()
      sumLossVal = 0.0
      all_labels = []
      all_preds = []

      with torch.no_grad():
          for batch in val_loader:
              batch = [t.to(device, non_blocking=True) for t in batch]
              xTensor = batch[:-1]
              labels = batch[-1]

              with torch.amp.autocast("cuda", dtype=torch.bfloat16):
                outputs = model(xTensor)

              loss = criterion(outputs, labels)


              # --- Predictions ---
              preds = torch.sigmoid(outputs) > threshold  # (batch_size, num_labels)

              # Move to CPU for sklearn
              all_labels.append(labels.cpu().numpy())
              all_preds.append(preds.cpu().numpy())

              sumLossVal += loss.item()

      meanLossVal = sumLossVal / len(val_loader)
      evalLosses.append(meanLossVal)

      end = time.perf_counter()

      # === Combine batches ===
      all_labels = np.concatenate(all_labels, axis=0)
      all_preds = np.concatenate(all_preds, axis=0)

      # === Metrics ===
      eval_metric = compute_eval_metrics(meanLossVal, all_labels, all_preds, labels_list)
      print_global_eval_metrics(eval_metric, exec_time = end - start)

      # === Take best f1 (Weighted average) ===
      eval_metric_epochs.append(eval_metric)
      eval_metric_epochs = eval_metric_epochs[-window_eval_mean:]
      eval_metric_epochs_mean = calc_eval_metric_epochs_mean(eval_metric_epochs) if len(eval_metric_epochs) >= window_eval_mean else None
      if eval_metric_epochs_mean is not None and best_f1 < eval_metric_epochs_mean['f1_micro']:
          best_f1 = eval_metric_epochs_mean['f1_micro']
          best_eval_metric = eval_metric_epochs_mean

      if no_improvements_stop is not None and no_improvements_stop == (epoch + 1) and best_f1 < 0.0000001:
          break

  return trainLosses, evalLosses, best_eval_metric
# Out:
# /tmp/ipykernel_460/1403387331.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bills'].fillna('', inplace=True)
# /tmp/ipykernel_460/1403387331.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['bills'].fillna('', inplace=True)

# %% [markdown]
# Hyperparams Search

# %%
def hyperparams_search(n_samples, epochs):
  batch_size = 4

  best_f1 = -9999
  best_hyperparams = None
  best_eval_metric = None
  best_trainLosses = None
  best_evalLosses = None

  for i in range(n_samples):
    disable_seed()
    hyperparams = {
        'lr': 10 ** random.uniform(-5.1, -3.1),
        'drop_out': random.uniform(0.05, 0.45),
        'd_a': random.choice([32, 64, 128, 256, 512]),
        'nhead': random.choice([4, 8, 12, 16]),
        'weight_decay': random.uniform(0.01, 0.1),
        'lr_dapt': 10 ** random.uniform(-5, -4.3),
        'warmup_ratio_dapt': random.uniform(0.03, 0.15),
        'max_steps_dapt': int(random.uniform(0, 500)),
        'stride_dapt': random.choice([0, 64, 128]),
    }
    set_seed(seed)
    print('hyperparams', hyperparams)

    trainLosses, evalLosses, eval_metric = train(
        epochs=epochs,
        batch_size=batch_size,
        hyperparams=hyperparams,
        no_improvements_stop=12
    )
    f1 = eval_metric['f1_micro']
    print('Training f1', f1, 'vs', 'Best f1', best_f1)

    if f1 > best_f1:
      best_f1 = f1
      best_hyperparams = hyperparams
      best_eval_metric = eval_metric
      best_trainLosses = trainLosses
      best_evalLosses = evalLosses

  print('best_f1', best_f1)
  print('best_hyperparams', best_hyperparams)

  return best_f1, best_hyperparams, best_eval_metric, best_trainLosses, best_evalLosses

# %% [markdown]
# Execute

# %%
# _, best_hyperparams, best_eval_metric, trainLosses, evalLosses = hyperparams_search(n_samples=50, epochs=50)
best_hyperparams = {
    'lr': 4.622359343917067e-05,
    'drop_out': 0.11002630901978275,
    'd_a': 32,
    'nhead': 12,
    'weight_decay': 0.05381949799402886,
    'lr_dapt': 1.2955460551589138e-05,
    'warmup_ratio_dapt': 0.14028828948011018,
    'max_steps_dapt': 325,
    'stride_dapt': 0
}

trainLosses, evalLosses, best_eval_metric = train(epochs=250, batch_size=8, hyperparams=best_hyperparams)
# Out:
# CONFIG: batch_size=8, epochs=250, device=cuda
#
# Init model CamembertHierachicalLsanClassifierDep(model_dapt=<class 'NoneType'>, model_name=camembert-base, num_labels=11, d_a=32, drop_out=0.11002630901978275 freeze_bert=False)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# CamembertModel LOAD REPORT from: camembert-base
# Key                       | Status     |  |
# --------------------------+------------+--+-
# lm_head.dense.weight      | UNEXPECTED |  |
# lm_head.layer_norm.weight | UNEXPECTED |  |
# lm_head.layer_norm.bias   | UNEXPECTED |  |
# lm_head.dense.bias        | UNEXPECTED |  |
# lm_head.bias              | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Epoch 1/250, Batch 14/14 - Loss: 0.5423  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000 (4.985793s)
# Epoch 2/250, Batch 14/14 - Loss: 0.5306  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000 (5.190914s)
# Epoch 3/250, Batch 14/14 - Loss: 0.5011  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000 (5.125267s)
# Epoch 4/250, Batch 14/14 - Loss: 0.4974  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000 (5.162855s)
# Epoch 5/250, Batch 14/14 - Loss: 0.4903  Accuracy: 0.0000 F1-Micro: 0.0000 F1-Macro-Avg 0.0000 Precision: 0.0000 Recall: 0.0000 (5.212862s)
# Epoch 6/250, Batch 14/14 - Loss: 0.4724  Accuracy: 0.0000 F1-Micro: 0.0220 F1-Macro-Avg 0.0182 Precision: 1.0000 Recall: 0.0111 (5.124191s)
# Epoch 7/250, Batch 14/14 - Loss: 0.4452  Accuracy: 0.0541 F1-Micro: 0.2136 F1-Macro-Avg 0.1486 Precision: 0.8462 Recall: 0.1222 (5.086567s)
# Epoch 8/250, Batch 14/14 - Loss: 0.4289  Accuracy: 0.1892 F1-Micro: 0.3243 F1-Macro-Avg 0.2403 Precision: 0.8571 Recall: 0.2000 (5.180770s)
# Epoch 9/250, Batch 14/14 - Loss: 0.3865  Accuracy: 0.1892 F1-Micro: 0.4590 F1-Macro-Avg 0.3436 Precision: 0.8750 Recall: 0.3111 (5.070597s)
# Epoch 10/250, Batch 14/14 - Loss: 0.3637  Accuracy: 0.2162 F1-Micro: 0.5000 F1-Macro-Avg 0.3674 Precision: 0.8421 Recall: 0.3556 (5.253623s)
# Epoch 11/250, Batch 14/14 - Loss: 0.3319  Accuracy: 0.1892 F1-Micro: 0.5630 F1-Macro-Avg 0.4822 Precision: 0.8444 Recall: 0.4222 (5.231842s)
# Epoch 12/250, Batch 14/14 - Loss: 0.3013  Accuracy: 0.2432 F1-Micro: 0.5469 F1-Macro-Avg 0.4750 Precision: 0.9211 Recall: 0.3889 (5.187365s)
# Epoch 13/250, Batch 14/14 - Loss: 0.2832  Accuracy: 0.2703 F1-Micro: 0.6377 F1-Macro-Avg 0.5781 Precision: 0.9167 Recall: 0.4889 (5.127859s)
# Epoch 14/250, Batch 14/14 - Loss: 0.2483  Accuracy: 0.2703 F1-Micro: 0.7114 F1-Macro-Avg 0.6453 Precision: 0.8983 Recall: 0.5889 (5.317063s)
# Epoch 15/250, Batch 14/14 - Loss: 0.2186  Accuracy: 0.2432 F1-Micro: 0.6761 F1-Macro-Avg 0.6482 Precision: 0.9231 Recall: 0.5333 (5.265012s)
# Epoch 16/250, Batch 14/14 - Loss: 0.1944  Accuracy: 0.3243 F1-Micro: 0.7237 F1-Macro-Avg 0.7072 Precision: 0.8871 Recall: 0.6111 (5.112444s)
# Epoch 17/250, Batch 14/14 - Loss: 0.1812  Accuracy: 0.2973 F1-Micro: 0.7514 F1-Macro-Avg 0.7211 Precision: 0.7831 Recall: 0.7222 (5.298295s)
# Epoch 18/250, Batch 14/14 - Loss: 0.1679  Accuracy: 0.4054 F1-Micro: 0.7805 F1-Macro-Avg 0.7578 Precision: 0.8649 Recall: 0.7111 (5.213483s)
# Epoch 19/250, Batch 14/14 - Loss: 0.1581  Accuracy: 0.5135 F1-Micro: 0.8242 F1-Macro-Avg 0.8244 Precision: 0.9067 Recall: 0.7556 (5.123951s)
# Epoch 20/250, Batch 14/14 - Loss: 0.1450  Accuracy: 0.4595 F1-Micro: 0.7882 F1-Macro-Avg 0.7547 Precision: 0.8375 Recall: 0.7444 (5.170949s)
# Epoch 21/250, Batch 14/14 - Loss: 0.1308  Accuracy: 0.4595 F1-Micro: 0.8049 F1-Macro-Avg 0.7851 Precision: 0.8919 Recall: 0.7333 (5.236865s)
# Epoch 22/250, Batch 14/14 - Loss: 0.1104  Accuracy: 0.5135 F1-Micro: 0.8199 F1-Macro-Avg 0.8048 Precision: 0.9296 Recall: 0.7333 (5.155009s)
# Epoch 23/250, Batch 14/14 - Loss: 0.0899  Accuracy: 0.6216 F1-Micro: 0.8721 F1-Macro-Avg 0.8668 Precision: 0.9146 Recall: 0.8333 (5.216861s)
# Epoch 24/250, Batch 14/14 - Loss: 0.0829  Accuracy: 0.5135 F1-Micro: 0.8125 F1-Macro-Avg 0.8091 Precision: 0.9286 Recall: 0.7222 (5.155193s)
# Epoch 25/250, Batch 14/14 - Loss: 0.0726  Accuracy: 0.4865 F1-Micro: 0.8171 F1-Macro-Avg 0.8010 Precision: 0.9054 Recall: 0.7444 (5.266079s)
# Epoch 26/250, Batch 14/14 - Loss: 0.0832  Accuracy: 0.5135 F1-Micro: 0.8304 F1-Macro-Avg 0.8283 Precision: 0.8765 Recall: 0.7889 (5.076768s)
# Epoch 27/250, Batch 14/14 - Loss: 0.1089  Accuracy: 0.5135 F1-Micro: 0.8295 F1-Macro-Avg 0.8152 Precision: 0.8488 Recall: 0.8111 (5.283404s)
# Epoch 28/250, Batch 14/14 - Loss: 0.0760  Accuracy: 0.5676 F1-Micro: 0.8639 F1-Macro-Avg 0.8447 Precision: 0.9241 Recall: 0.8111 (5.266467s)
# Epoch 29/250, Batch 14/14 - Loss: 0.0621  Accuracy: 0.5946 F1-Micro: 0.8519 F1-Macro-Avg 0.8339 Precision: 0.9583 Recall: 0.7667 (5.264017s)
# Epoch 30/250, Batch 14/14 - Loss: 0.0539  Accuracy: 0.5405 F1-Micro: 0.8743 F1-Macro-Avg 0.8691 Precision: 0.9481 Recall: 0.8111 (5.084686s)
# Epoch 31/250, Batch 14/14 - Loss: 0.0482  Accuracy: 0.6216 F1-Micro: 0.8485 F1-Macro-Avg 0.8240 Precision: 0.9333 Recall: 0.7778 (5.296043s)
# Epoch 32/250, Batch 14/14 - Loss: 0.0460  Accuracy: 0.4865 F1-Micro: 0.8537 F1-Macro-Avg 0.8398 Precision: 0.9459 Recall: 0.7778 (5.221291s)
# Epoch 33/250, Batch 14/14 - Loss: 0.0391  Accuracy: 0.5676 F1-Micro: 0.8639 F1-Macro-Avg 0.8516 Precision: 0.9241 Recall: 0.8111 (5.205130s)
# Epoch 34/250, Batch 14/14 - Loss: 0.0338  Accuracy: 0.5676 F1-Micro: 0.8690 F1-Macro-Avg 0.8632 Precision: 0.9359 Recall: 0.8111 (5.200633s)
# Epoch 35/250, Batch 14/14 - Loss: 0.0339  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.261903s)
# Epoch 36/250, Batch 14/14 - Loss: 0.0318  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8871 Precision: 0.9383 Recall: 0.8444 (5.069858s)
# Epoch 37/250, Batch 14/14 - Loss: 0.0293  Accuracy: 0.5676 F1-Micro: 0.8434 F1-Macro-Avg 0.8220 Precision: 0.9211 Recall: 0.7778 (5.118806s)
# Epoch 38/250, Batch 14/14 - Loss: 0.0314  Accuracy: 0.5946 F1-Micro: 0.8795 F1-Macro-Avg 0.8707 Precision: 0.9605 Recall: 0.8111 (5.262685s)
# Epoch 39/250, Batch 14/14 - Loss: 0.0311  Accuracy: 0.5946 F1-Micro: 0.8757 F1-Macro-Avg 0.8564 Precision: 0.9367 Recall: 0.8222 (5.203341s)
# Epoch 40/250, Batch 14/14 - Loss: 0.0276  Accuracy: 0.5946 F1-Micro: 0.8690 F1-Macro-Avg 0.8528 Precision: 0.9359 Recall: 0.8111 (5.248184s)
# Epoch 41/250, Batch 14/14 - Loss: 0.0243  Accuracy: 0.5676 F1-Micro: 0.8772 F1-Macro-Avg 0.8668 Precision: 0.9259 Recall: 0.8333 (5.043661s)
# Epoch 42/250, Batch 14/14 - Loss: 0.0209  Accuracy: 0.5946 F1-Micro: 0.8721 F1-Macro-Avg 0.8573 Precision: 0.9146 Recall: 0.8333 (5.221970s)
# Epoch 43/250, Batch 14/14 - Loss: 0.0206  Accuracy: 0.6216 F1-Micro: 0.8800 F1-Macro-Avg 0.8668 Precision: 0.9059 Recall: 0.8556 (5.245439s)
# Epoch 44/250, Batch 14/14 - Loss: 0.0182  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8752 Precision: 0.9383 Recall: 0.8444 (5.273713s)
# Epoch 45/250, Batch 14/14 - Loss: 0.0169  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8921 Precision: 0.9390 Recall: 0.8556 (5.307264s)
# Epoch 46/250, Batch 14/14 - Loss: 0.0168  Accuracy: 0.5946 F1-Micro: 0.8929 F1-Macro-Avg 0.8779 Precision: 0.9615 Recall: 0.8333 (5.153349s)
# Epoch 47/250, Batch 14/14 - Loss: 0.0168  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8778 Precision: 0.9167 Recall: 0.8556 (5.197621s)
# Epoch 48/250, Batch 14/14 - Loss: 0.0166  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8865 Precision: 0.9500 Recall: 0.8444 (5.186847s)
# Epoch 49/250, Batch 14/14 - Loss: 0.0153  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8865 Precision: 0.9383 Recall: 0.8444 (5.203118s)
# Epoch 50/250, Batch 14/14 - Loss: 0.0155  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.8967 Precision: 0.9294 Recall: 0.8778 (5.309022s)
# Epoch 51/250, Batch 14/14 - Loss: 0.0164  Accuracy: 0.6486 F1-Micro: 0.9059 F1-Macro-Avg 0.9008 Precision: 0.9625 Recall: 0.8556 (5.265530s)
# Epoch 52/250, Batch 14/14 - Loss: 0.0153  Accuracy: 0.5946 F1-Micro: 0.8757 F1-Macro-Avg 0.8703 Precision: 0.9367 Recall: 0.8222 (5.289012s)
# Epoch 53/250, Batch 14/14 - Loss: 0.0133  Accuracy: 0.6216 F1-Micro: 0.8941 F1-Macro-Avg 0.8781 Precision: 0.9500 Recall: 0.8444 (5.177829s)
# Epoch 54/250, Batch 14/14 - Loss: 0.0131  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.180066s)
# Epoch 55/250, Batch 14/14 - Loss: 0.0113  Accuracy: 0.5946 F1-Micro: 0.8837 F1-Macro-Avg 0.8824 Precision: 0.9268 Recall: 0.8444 (5.053106s)
# Epoch 56/250, Batch 14/14 - Loss: 0.0111  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8935 Precision: 0.9390 Recall: 0.8556 (5.225020s)
# Epoch 57/250, Batch 14/14 - Loss: 0.0107  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8915 Precision: 0.9390 Recall: 0.8556 (5.235188s)
# Epoch 58/250, Batch 14/14 - Loss: 0.0106  Accuracy: 0.6486 F1-Micro: 0.9059 F1-Macro-Avg 0.9008 Precision: 0.9625 Recall: 0.8556 (5.205666s)
# Epoch 59/250, Batch 14/14 - Loss: 0.0098  Accuracy: 0.6216 F1-Micro: 0.8864 F1-Macro-Avg 0.8819 Precision: 0.9070 Recall: 0.8667 (5.211096s)
# Epoch 60/250, Batch 14/14 - Loss: 0.0105  Accuracy: 0.6216 F1-Micro: 0.9006 F1-Macro-Avg 0.8977 Precision: 0.9506 Recall: 0.8556 (5.086837s)
# Epoch 61/250, Batch 14/14 - Loss: 0.0096  Accuracy: 0.6486 F1-Micro: 0.9006 F1-Macro-Avg 0.8967 Precision: 0.9506 Recall: 0.8556 (5.159767s)
# Epoch 62/250, Batch 14/14 - Loss: 0.0085  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8894 Precision: 0.9500 Recall: 0.8444 (5.231693s)
# Epoch 63/250, Batch 14/14 - Loss: 0.0100  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8908 Precision: 0.9186 Recall: 0.8778 (5.265547s)
# Epoch 64/250, Batch 14/14 - Loss: 0.0102  Accuracy: 0.6216 F1-Micro: 0.9006 F1-Macro-Avg 0.8977 Precision: 0.9506 Recall: 0.8556 (5.272094s)
# Epoch 65/250, Batch 14/14 - Loss: 0.0088  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.095213s)
# Epoch 66/250, Batch 14/14 - Loss: 0.0083  Accuracy: 0.6216 F1-Micro: 0.9006 F1-Macro-Avg 0.8948 Precision: 0.9506 Recall: 0.8556 (5.246730s)
# Epoch 67/250, Batch 14/14 - Loss: 0.0086  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8915 Precision: 0.9390 Recall: 0.8556 (5.134649s)
# Epoch 68/250, Batch 14/14 - Loss: 0.0090  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8922 Precision: 0.9286 Recall: 0.8667 (5.014356s)
# Epoch 69/250, Batch 14/14 - Loss: 0.0085  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8888 Precision: 0.9176 Recall: 0.8667 (5.287196s)
# Epoch 70/250, Batch 14/14 - Loss: 0.0092  Accuracy: 0.5405 F1-Micro: 0.8772 F1-Macro-Avg 0.8752 Precision: 0.9259 Recall: 0.8333 (5.222797s)
# Epoch 71/250, Batch 14/14 - Loss: 0.0083  Accuracy: 0.5676 F1-Micro: 0.8848 F1-Macro-Avg 0.8722 Precision: 0.9733 Recall: 0.8111 (5.213673s)
# Epoch 72/250, Batch 14/14 - Loss: 0.0082  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8939 Precision: 0.9390 Recall: 0.8556 (4.961191s)
# Epoch 73/250, Batch 14/14 - Loss: 0.0068  Accuracy: 0.5946 F1-Micro: 0.8837 F1-Macro-Avg 0.8774 Precision: 0.9268 Recall: 0.8444 (5.160211s)
# Epoch 74/250, Batch 14/14 - Loss: 0.0067  Accuracy: 0.5946 F1-Micro: 0.8837 F1-Macro-Avg 0.8777 Precision: 0.9268 Recall: 0.8444 (5.216393s)
# Epoch 75/250, Batch 14/14 - Loss: 0.0089  Accuracy: 0.5405 F1-Micro: 0.8772 F1-Macro-Avg 0.8765 Precision: 0.9259 Recall: 0.8333 (5.089313s)
# Epoch 76/250, Batch 14/14 - Loss: 0.0088  Accuracy: 0.5946 F1-Micro: 0.8966 F1-Macro-Avg 0.8923 Precision: 0.9286 Recall: 0.8667 (5.275588s)
# Epoch 77/250, Batch 14/14 - Loss: 0.0098  Accuracy: 0.5946 F1-Micro: 0.8690 F1-Macro-Avg 0.8633 Precision: 0.9359 Recall: 0.8111 (5.249828s)
# Epoch 78/250, Batch 14/14 - Loss: 0.0078  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8886 Precision: 0.9390 Recall: 0.8556 (5.336523s)
# Epoch 79/250, Batch 14/14 - Loss: 0.0070  Accuracy: 0.6757 F1-Micro: 0.8966 F1-Macro-Avg 0.8975 Precision: 0.9286 Recall: 0.8667 (5.154180s)
# Epoch 80/250, Batch 14/14 - Loss: 0.0060  Accuracy: 0.5676 F1-Micro: 0.8889 F1-Macro-Avg 0.8811 Precision: 0.9383 Recall: 0.8444 (5.275776s)
# Epoch 81/250, Batch 14/14 - Loss: 0.0057  Accuracy: 0.5946 F1-Micro: 0.8837 F1-Macro-Avg 0.8801 Precision: 0.9268 Recall: 0.8444 (5.275047s)
# Epoch 82/250, Batch 14/14 - Loss: 0.0050  Accuracy: 0.5676 F1-Micro: 0.8786 F1-Macro-Avg 0.8773 Precision: 0.9157 Recall: 0.8444 (5.253781s)
# Epoch 83/250, Batch 14/14 - Loss: 0.0050  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.168358s)
# Epoch 84/250, Batch 14/14 - Loss: 0.0051  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8815 Precision: 0.9268 Recall: 0.8444 (5.122117s)
# Epoch 85/250, Batch 14/14 - Loss: 0.0052  Accuracy: 0.6757 F1-Micro: 0.9123 F1-Macro-Avg 0.9059 Precision: 0.9630 Recall: 0.8667 (5.271133s)
# Epoch 86/250, Batch 14/14 - Loss: 0.0048  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8915 Precision: 0.9390 Recall: 0.8556 (5.248159s)
# Epoch 87/250, Batch 14/14 - Loss: 0.0053  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8882 Precision: 0.9277 Recall: 0.8556 (5.171153s)
# Epoch 88/250, Batch 14/14 - Loss: 0.0049  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8865 Precision: 0.9500 Recall: 0.8444 (5.119632s)
# Epoch 89/250, Batch 14/14 - Loss: 0.0046  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.195866s)
# Epoch 90/250, Batch 14/14 - Loss: 0.0041  Accuracy: 0.6216 F1-Micro: 0.8994 F1-Macro-Avg 0.8926 Precision: 0.9620 Recall: 0.8444 (5.236912s)
# Epoch 91/250, Batch 14/14 - Loss: 0.0042  Accuracy: 0.5676 F1-Micro: 0.8889 F1-Macro-Avg 0.8833 Precision: 0.9383 Recall: 0.8444 (5.249092s)
# Epoch 92/250, Batch 14/14 - Loss: 0.0036  Accuracy: 0.6216 F1-Micro: 0.9006 F1-Macro-Avg 0.8944 Precision: 0.9506 Recall: 0.8556 (5.274875s)
# Epoch 93/250, Batch 14/14 - Loss: 0.0041  Accuracy: 0.6486 F1-Micro: 0.9059 F1-Macro-Avg 0.8977 Precision: 0.9625 Recall: 0.8556 (5.181052s)
# Epoch 94/250, Batch 14/14 - Loss: 0.0039  Accuracy: 0.5946 F1-Micro: 0.8953 F1-Macro-Avg 0.8884 Precision: 0.9390 Recall: 0.8556 (5.176618s)
# Epoch 95/250, Batch 14/14 - Loss: 0.0039  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8915 Precision: 0.9277 Recall: 0.8556 (5.207177s)
# Epoch 96/250, Batch 14/14 - Loss: 0.0039  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8823 Precision: 0.9383 Recall: 0.8444 (5.206585s)
# Epoch 97/250, Batch 14/14 - Loss: 0.0038  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9014 Precision: 0.9294 Recall: 0.8778 (5.043549s)
# Epoch 98/250, Batch 14/14 - Loss: 0.0037  Accuracy: 0.5946 F1-Micro: 0.8953 F1-Macro-Avg 0.8884 Precision: 0.9390 Recall: 0.8556 (5.204547s)
# Epoch 99/250, Batch 14/14 - Loss: 0.0034  Accuracy: 0.6216 F1-Micro: 0.8837 F1-Macro-Avg 0.8785 Precision: 0.9268 Recall: 0.8444 (5.217796s)
# Epoch 100/250, Batch 14/14 - Loss: 0.0036  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8842 Precision: 0.9383 Recall: 0.8444 (5.342943s)
# Epoch 101/250, Batch 14/14 - Loss: 0.0034  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8848 Precision: 0.9383 Recall: 0.8444 (5.250718s)
# Epoch 102/250, Batch 14/14 - Loss: 0.0042  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8908 Precision: 0.9500 Recall: 0.8444 (5.267114s)
# Epoch 103/250, Batch 14/14 - Loss: 0.0039  Accuracy: 0.6486 F1-Micro: 0.9029 F1-Macro-Avg 0.9052 Precision: 0.9294 Recall: 0.8778 (5.244111s)
# Epoch 104/250, Batch 14/14 - Loss: 0.0039  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8805 Precision: 0.9268 Recall: 0.8444 (5.204157s)
# Epoch 105/250, Batch 14/14 - Loss: 0.0031  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8838 Precision: 0.9176 Recall: 0.8667 (5.291437s)
# Epoch 106/250, Batch 14/14 - Loss: 0.0038  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8897 Precision: 0.9277 Recall: 0.8556 (5.016201s)
# Epoch 107/250, Batch 14/14 - Loss: 0.0031  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.210241s)
# Epoch 108/250, Batch 14/14 - Loss: 0.0030  Accuracy: 0.6486 F1-Micro: 0.9059 F1-Macro-Avg 0.9008 Precision: 0.9625 Recall: 0.8556 (4.987006s)
# Epoch 109/250, Batch 14/14 - Loss: 0.0030  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.197697s)
# Epoch 110/250, Batch 14/14 - Loss: 0.0031  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8997 Precision: 0.9398 Recall: 0.8667 (5.111571s)
# Epoch 111/250, Batch 14/14 - Loss: 0.0030  Accuracy: 0.6216 F1-Micro: 0.8864 F1-Macro-Avg 0.8795 Precision: 0.9070 Recall: 0.8667 (5.217589s)
# Epoch 112/250, Batch 14/14 - Loss: 0.0029  Accuracy: 0.6486 F1-Micro: 0.9029 F1-Macro-Avg 0.8996 Precision: 0.9294 Recall: 0.8778 (5.332528s)
# Epoch 113/250, Batch 14/14 - Loss: 0.0029  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8849 Precision: 0.9277 Recall: 0.8556 (5.176999s)
# Epoch 114/250, Batch 14/14 - Loss: 0.0027  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8833 Precision: 0.9383 Recall: 0.8444 (5.107187s)
# Epoch 115/250, Batch 14/14 - Loss: 0.0027  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8922 Precision: 0.9286 Recall: 0.8667 (5.202946s)
# Epoch 116/250, Batch 14/14 - Loss: 0.0025  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8865 Precision: 0.9500 Recall: 0.8444 (5.232271s)
# Epoch 117/250, Batch 14/14 - Loss: 0.0026  Accuracy: 0.5676 F1-Micro: 0.8786 F1-Macro-Avg 0.8763 Precision: 0.9157 Recall: 0.8444 (5.186496s)
# Epoch 118/250, Batch 14/14 - Loss: 0.0024  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8805 Precision: 0.9268 Recall: 0.8444 (5.271987s)
# Epoch 119/250, Batch 14/14 - Loss: 0.0026  Accuracy: 0.6216 F1-Micro: 0.8941 F1-Macro-Avg 0.8894 Precision: 0.9500 Recall: 0.8444 (5.204836s)
# Epoch 120/250, Batch 14/14 - Loss: 0.0024  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8822 Precision: 0.9167 Recall: 0.8556 (5.248630s)
# Epoch 121/250, Batch 14/14 - Loss: 0.0027  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8956 Precision: 0.9286 Recall: 0.8667 (5.161902s)
# Epoch 122/250, Batch 14/14 - Loss: 0.0024  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8818 Precision: 0.9167 Recall: 0.8556 (5.044048s)
# Epoch 123/250, Batch 14/14 - Loss: 0.0024  Accuracy: 0.6216 F1-Micro: 0.8941 F1-Macro-Avg 0.8884 Precision: 0.9500 Recall: 0.8444 (5.202309s)
# Epoch 124/250, Batch 14/14 - Loss: 0.0023  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.157095s)
# Epoch 125/250, Batch 14/14 - Loss: 0.0023  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8792 Precision: 0.9268 Recall: 0.8444 (5.268439s)
# Epoch 126/250, Batch 14/14 - Loss: 0.0021  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8805 Precision: 0.9268 Recall: 0.8444 (5.122885s)
# Epoch 127/250, Batch 14/14 - Loss: 0.0021  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8964 Precision: 0.9398 Recall: 0.8667 (5.241686s)
# Epoch 128/250, Batch 14/14 - Loss: 0.0028  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8937 Precision: 0.9286 Recall: 0.8667 (5.263104s)
# Epoch 129/250, Batch 14/14 - Loss: 0.0028  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8770 Precision: 0.9277 Recall: 0.8556 (5.139000s)
# Epoch 130/250, Batch 14/14 - Loss: 0.0022  Accuracy: 0.5946 F1-Micro: 0.8941 F1-Macro-Avg 0.8865 Precision: 0.9500 Recall: 0.8444 (5.225312s)
# Epoch 131/250, Batch 14/14 - Loss: 0.0023  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.199817s)
# Epoch 132/250, Batch 14/14 - Loss: 0.0023  Accuracy: 0.5946 F1-Micro: 0.8876 F1-Macro-Avg 0.8845 Precision: 0.9494 Recall: 0.8333 (5.216778s)
# Epoch 133/250, Batch 14/14 - Loss: 0.0022  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8974 Precision: 0.9398 Recall: 0.8667 (5.229141s)
# Epoch 134/250, Batch 14/14 - Loss: 0.0026  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9014 Precision: 0.9294 Recall: 0.8778 (5.089728s)
# Epoch 135/250, Batch 14/14 - Loss: 0.0024  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8895 Precision: 0.9176 Recall: 0.8667 (5.185260s)
# Epoch 136/250, Batch 14/14 - Loss: 0.0022  Accuracy: 0.6216 F1-Micro: 0.9017 F1-Macro-Avg 0.8943 Precision: 0.9398 Recall: 0.8667 (5.293484s)
# Epoch 137/250, Batch 14/14 - Loss: 0.0020  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8897 Precision: 0.9277 Recall: 0.8556 (5.252863s)
# Epoch 138/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.6216 F1-Micro: 0.8837 F1-Macro-Avg 0.8820 Precision: 0.9268 Recall: 0.8444 (5.202252s)
# Epoch 139/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.184567s)
# Epoch 140/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.231195s)
# Epoch 141/250, Batch 14/14 - Loss: 0.0016  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8874 Precision: 0.9277 Recall: 0.8556 (5.298983s)
# Epoch 142/250, Batch 14/14 - Loss: 0.0016  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (4.981848s)
# Epoch 143/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.6216 F1-Micro: 0.9029 F1-Macro-Avg 0.8982 Precision: 0.9294 Recall: 0.8778 (5.226472s)
# Epoch 144/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.5946 F1-Micro: 0.8953 F1-Macro-Avg 0.8884 Precision: 0.9390 Recall: 0.8556 (5.103346s)
# Epoch 145/250, Batch 14/14 - Loss: 0.0017  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.9014 Precision: 0.9294 Recall: 0.8778 (5.205476s)
# Epoch 146/250, Batch 14/14 - Loss: 0.0019  Accuracy: 0.6216 F1-Micro: 0.9006 F1-Macro-Avg 0.8948 Precision: 0.9506 Recall: 0.8556 (5.229227s)
# Epoch 147/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.269603s)
# Epoch 148/250, Batch 14/14 - Loss: 0.0016  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.218809s)
# Epoch 149/250, Batch 14/14 - Loss: 0.0016  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8932 Precision: 0.9286 Recall: 0.8667 (5.149915s)
# Epoch 150/250, Batch 14/14 - Loss: 0.0018  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.134112s)
# Epoch 151/250, Batch 14/14 - Loss: 0.0017  Accuracy: 0.5676 F1-Micro: 0.8876 F1-Macro-Avg 0.8855 Precision: 0.9494 Recall: 0.8333 (5.156420s)
# Epoch 152/250, Batch 14/14 - Loss: 0.0017  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.246599s)
# Epoch 153/250, Batch 14/14 - Loss: 0.0015  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8895 Precision: 0.9176 Recall: 0.8667 (5.054303s)
# Epoch 154/250, Batch 14/14 - Loss: 0.0016  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8818 Precision: 0.9167 Recall: 0.8556 (5.272262s)
# Epoch 155/250, Batch 14/14 - Loss: 0.0015  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.282453s)
# Epoch 156/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5676 F1-Micro: 0.8889 F1-Macro-Avg 0.8833 Precision: 0.9383 Recall: 0.8444 (5.285737s)
# Epoch 157/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8935 Precision: 0.9390 Recall: 0.8556 (5.257776s)
# Epoch 158/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.045086s)
# Epoch 159/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.5946 F1-Micro: 0.8786 F1-Macro-Avg 0.8759 Precision: 0.9157 Recall: 0.8444 (5.313954s)
# Epoch 160/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.5676 F1-Micro: 0.8786 F1-Macro-Avg 0.8763 Precision: 0.9157 Recall: 0.8444 (5.276152s)
# Epoch 161/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8823 Precision: 0.9383 Recall: 0.8444 (5.224249s)
# Epoch 162/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.227256s)
# Epoch 163/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.021482s)
# Epoch 164/250, Batch 14/14 - Loss: 0.0011  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8792 Precision: 0.9268 Recall: 0.8444 (5.296981s)
# Epoch 165/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.157253s)
# Epoch 166/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.270856s)
# Epoch 167/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.6216 F1-Micro: 0.8889 F1-Macro-Avg 0.8894 Precision: 0.9383 Recall: 0.8444 (5.175499s)
# Epoch 168/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.5676 F1-Micro: 0.8772 F1-Macro-Avg 0.8751 Precision: 0.9259 Recall: 0.8333 (5.268637s)
# Epoch 169/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.6216 F1-Micro: 0.9029 F1-Macro-Avg 0.8995 Precision: 0.9294 Recall: 0.8778 (5.242672s)
# Epoch 170/250, Batch 14/14 - Loss: 0.0013  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8933 Precision: 0.9398 Recall: 0.8667 (5.295680s)
# Epoch 171/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8875 Precision: 0.9383 Recall: 0.8444 (5.237548s)
# Epoch 172/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5946 F1-Micro: 0.8837 F1-Macro-Avg 0.8797 Precision: 0.9268 Recall: 0.8444 (5.197248s)
# Epoch 173/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.6486 F1-Micro: 0.9029 F1-Macro-Avg 0.9037 Precision: 0.9294 Recall: 0.8778 (5.257683s)
# Epoch 174/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.040202s)
# Epoch 175/250, Batch 14/14 - Loss: 0.0014  Accuracy: 0.5946 F1-Micro: 0.8889 F1-Macro-Avg 0.8852 Precision: 0.9383 Recall: 0.8444 (5.220331s)
# Epoch 176/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.6486 F1-Micro: 0.8977 F1-Macro-Avg 0.8924 Precision: 0.9186 Recall: 0.8778 (5.156166s)
# Epoch 177/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8974 Precision: 0.9398 Recall: 0.8667 (5.249341s)
# Epoch 178/250, Batch 14/14 - Loss: 0.0011  Accuracy: 0.6216 F1-Micro: 0.9029 F1-Macro-Avg 0.8982 Precision: 0.9294 Recall: 0.8778 (5.313304s)
# Epoch 179/250, Batch 14/14 - Loss: 0.0011  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.130231s)
# Epoch 180/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.6216 F1-Micro: 0.9029 F1-Macro-Avg 0.8982 Precision: 0.9294 Recall: 0.8778 (5.176748s)
# Epoch 181/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8874 Precision: 0.9277 Recall: 0.8556 (5.199699s)
# Epoch 182/250, Batch 14/14 - Loss: 0.0011  Accuracy: 0.5676 F1-Micro: 0.8786 F1-Macro-Avg 0.8773 Precision: 0.9157 Recall: 0.8444 (5.203147s)
# Epoch 183/250, Batch 14/14 - Loss: 0.0012  Accuracy: 0.6486 F1-Micro: 0.9029 F1-Macro-Avg 0.8953 Precision: 0.9294 Recall: 0.8778 (5.286749s)
# Epoch 184/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8842 Precision: 0.9277 Recall: 0.8556 (5.232395s)
# Epoch 185/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6757 F1-Micro: 0.9080 F1-Macro-Avg 0.9014 Precision: 0.9405 Recall: 0.8778 (5.209880s)
# Epoch 186/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (4.996975s)
# Epoch 187/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6757 F1-Micro: 0.9080 F1-Macro-Avg 0.9014 Precision: 0.9405 Recall: 0.8778 (5.185640s)
# Epoch 188/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.316328s)
# Epoch 189/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.234767s)
# Epoch 190/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6486 F1-Micro: 0.8914 F1-Macro-Avg 0.8844 Precision: 0.9176 Recall: 0.8667 (5.070485s)
# Epoch 191/250, Batch 14/14 - Loss: 0.0010  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.287633s)
# Epoch 192/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8901 Precision: 0.9277 Recall: 0.8556 (5.182470s)
# Epoch 193/250, Batch 14/14 - Loss: 0.0010  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.172014s)
# Epoch 194/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8903 Precision: 0.9390 Recall: 0.8556 (5.176550s)
# Epoch 195/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.230157s)
# Epoch 196/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.253575s)
# Epoch 197/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8961 Precision: 0.9398 Recall: 0.8667 (5.201664s)
# Epoch 198/250, Batch 14/14 - Loss: 0.0009  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.175985s)
# Epoch 199/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.5946 F1-Micro: 0.8953 F1-Macro-Avg 0.8884 Precision: 0.9390 Recall: 0.8556 (5.254617s)
# Epoch 200/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8961 Precision: 0.9398 Recall: 0.8667 (5.254329s)
# Epoch 201/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.166912s)
# Epoch 202/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8974 Precision: 0.9398 Recall: 0.8667 (5.204104s)
# Epoch 203/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.158251s)
# Epoch 204/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.249584s)
# Epoch 205/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.134340s)
# Epoch 206/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.254049s)
# Epoch 207/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.198103s)
# Epoch 208/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6486 F1-Micro: 0.8977 F1-Macro-Avg 0.8924 Precision: 0.9186 Recall: 0.8778 (5.273810s)
# Epoch 209/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.5676 F1-Micro: 0.8837 F1-Macro-Avg 0.8815 Precision: 0.9268 Recall: 0.8444 (5.138919s)
# Epoch 210/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8816 Precision: 0.9167 Recall: 0.8556 (5.245670s)
# Epoch 211/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8818 Precision: 0.9167 Recall: 0.8556 (5.144954s)
# Epoch 212/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6757 F1-Micro: 0.9080 F1-Macro-Avg 0.9057 Precision: 0.9405 Recall: 0.8778 (5.200887s)
# Epoch 213/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6486 F1-Micro: 0.8977 F1-Macro-Avg 0.8954 Precision: 0.9186 Recall: 0.8778 (5.188922s)
# Epoch 214/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.224875s)
# Epoch 215/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.312228s)
# Epoch 216/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8854 Precision: 0.9277 Recall: 0.8556 (5.158588s)
# Epoch 217/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.5946 F1-Micro: 0.8902 F1-Macro-Avg 0.8850 Precision: 0.9277 Recall: 0.8556 (5.079460s)
# Epoch 218/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8902 F1-Macro-Avg 0.8873 Precision: 0.9277 Recall: 0.8556 (5.340085s)
# Epoch 219/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.178991s)
# Epoch 220/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6486 F1-Micro: 0.9017 F1-Macro-Avg 0.8985 Precision: 0.9398 Recall: 0.8667 (5.111508s)
# Epoch 221/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.035492s)
# Epoch 222/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8956 Precision: 0.9286 Recall: 0.8667 (5.154024s)
# Epoch 223/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6757 F1-Micro: 0.9029 F1-Macro-Avg 0.8977 Precision: 0.9294 Recall: 0.8778 (5.264996s)
# Epoch 224/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8962 Precision: 0.9286 Recall: 0.8667 (5.224838s)
# Epoch 225/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6757 F1-Micro: 0.9143 F1-Macro-Avg 0.9061 Precision: 0.9412 Recall: 0.8889 (5.135539s)
# Epoch 226/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8929 Precision: 0.9286 Recall: 0.8667 (5.345505s)
# Epoch 227/250, Batch 14/14 - Loss: 0.0008  Accuracy: 0.6486 F1-Micro: 0.9080 F1-Macro-Avg 0.9022 Precision: 0.9405 Recall: 0.8778 (5.116365s)
# Epoch 228/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6486 F1-Micro: 0.8977 F1-Macro-Avg 0.8954 Precision: 0.9186 Recall: 0.8778 (5.287695s)
# Epoch 229/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.151747s)
# Epoch 230/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6757 F1-Micro: 0.8977 F1-Macro-Avg 0.8938 Precision: 0.9186 Recall: 0.8778 (5.183261s)
# Epoch 231/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8915 Precision: 0.9390 Recall: 0.8556 (5.215452s)
# Epoch 232/250, Batch 14/14 - Loss: 0.0007  Accuracy: 0.6486 F1-Micro: 0.8914 F1-Macro-Avg 0.8856 Precision: 0.9176 Recall: 0.8667 (5.318595s)
# Epoch 233/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8914 Precision: 0.9286 Recall: 0.8667 (5.234612s)
# Epoch 234/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6486 F1-Micro: 0.9029 F1-Macro-Avg 0.8983 Precision: 0.9294 Recall: 0.8778 (5.229278s)
# Epoch 235/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8800 F1-Macro-Avg 0.8742 Precision: 0.9059 Recall: 0.8556 (5.270099s)
# Epoch 236/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.5946 F1-Micro: 0.8800 F1-Macro-Avg 0.8737 Precision: 0.9059 Recall: 0.8556 (5.236645s)
# Epoch 237/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8956 Precision: 0.9286 Recall: 0.8667 (5.181782s)
# Epoch 238/250, Batch 14/14 - Loss: 0.0006  Accuracy: 0.5946 F1-Micro: 0.8851 F1-Macro-Avg 0.8813 Precision: 0.9167 Recall: 0.8556 (5.310139s)
# Epoch 239/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8935 Precision: 0.9390 Recall: 0.8556 (5.289570s)
# Epoch 240/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8895 Precision: 0.9176 Recall: 0.8667 (5.117533s)
# Epoch 241/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8953 F1-Macro-Avg 0.8903 Precision: 0.9390 Recall: 0.8556 (5.228046s)
# Epoch 242/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.5946 F1-Micro: 0.8800 F1-Macro-Avg 0.8737 Precision: 0.9059 Recall: 0.8556 (5.124045s)
# Epoch 243/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.218492s)
# Epoch 244/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8903 Precision: 0.9286 Recall: 0.8667 (5.190862s)
# Epoch 245/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8956 Precision: 0.9286 Recall: 0.8667 (5.229159s)
# Epoch 246/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8914 F1-Macro-Avg 0.8871 Precision: 0.9176 Recall: 0.8667 (5.275725s)
# Epoch 247/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6486 F1-Micro: 0.8966 F1-Macro-Avg 0.8932 Precision: 0.9286 Recall: 0.8667 (5.132664s)
# Epoch 248/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8966 F1-Macro-Avg 0.8901 Precision: 0.9286 Recall: 0.8667 (5.252853s)
# Epoch 249/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6486 F1-Micro: 0.8977 F1-Macro-Avg 0.8954 Precision: 0.9186 Recall: 0.8778 (5.199032s)
# Epoch 250/250, Batch 14/14 - Loss: 0.0005  Accuracy: 0.6216 F1-Micro: 0.8851 F1-Macro-Avg 0.8818 Precision: 0.9167 Recall: 0.8556 (5.113793s)

# %%
plot_losses(trainLosses, evalLosses)

# %%
globalMetricsDf, labelMetricsDf = eval_metrics_to_df(best_eval_metric)

# %%
globalMetricsDf
# Out:
#        loss  accuracy  precision    recall  f1_micro  f1_macro_avg  \
# 0  0.111461  0.648649   0.930769  0.874603  0.901796      0.898011
#
#    f1_weighted_avg
# 0         0.898399

# %%
labelMetricsDf
# Out:
#                                       precision    recall  f1-score  support
# stimulation_dame_compagnie             1.000000  0.857143  0.923077      7.0
# aide_hygiene_personnelle               0.942857  0.657143  0.764286      5.0
# nourrir_personne                       1.000000  1.000000  1.000000      8.0
# cuisiner                               1.000000  0.714286  0.833333      7.0
# mobilite_transport_accompagnement_rv   0.789111  0.750000  0.767871     12.0
# mobilite_confort                       1.000000  1.000000  1.000000      9.0
# logistique_medicale                    0.857143  0.857143  0.857143      7.0
# menage_epoussetage                     1.000000  0.904762  0.948052      6.0
# menage_plancher                        0.946429  1.000000  0.971429      7.0
# menage_lessive                         0.924423  0.814286  0.859116     10.0
# commission_faire_marche                0.922161  0.988095  0.953810     12.0
